# %% [markdown]
# <a href="https://colab.research.google.com/github/drksnip/Research_for_Designing_Boring_Tool_Holder/blob/main/StaticBore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
==========================================================================
STATIC Boring Bar — GA-Driven Multi-Objective Optimization
==========================================================================
Configuration: the boring bar itself is STATIONARY (clamped in a
non-rotating holder); the WORKPIECE rotates (standard lathe/turning-
centre boring). This is the classical Tobias/Altintas regenerative-
chatter configuration, and it is physically simpler than a rotary
(self-rotating) boring bar:

  * The bar never spins, so its own rotation speed Omega_bar = 0 at all
    times.  Three effects that only exist because a beam is spinning
    about its own axis therefore DROP OUT ENTIRELY:
        - gyroscopic moment coupling      (rho*Ip term)
        - rotating-frame translational Coriolis coupling (rho*A term)
        - centrifugal softening of bending stiffness      (rho*A term)
    A stationary, circular (axisymmetric) beam has NO x/y cross-coupling:
    a tip force in x only ever produces tip motion in x.  So Hxy == 0
    identically, and the beam's FRF Hxx(w) does not depend on spindle
    (workpiece) speed at all.
  * The TC tuned-mass absorber lives inside the (non-rotating) bar, so
    it likewise has no Coriolis/centrifugal terms — it is a plain
    spring-mass-damper vibration absorber.
  * Workpiece rotation still matters, but ONLY through the regenerative
    chatter mechanism: successive tool passes are separated by one
    workpiece revolution, T = 60/RPM, and that phase delay is what
    turns a stationary FRF into speed-dependent stability lobes.  This
    is exactly how the mode-resolved stability-lobe-diagram code below
    already worked (it evaluated the FRF at Omega=0 and only varied the
    regeneration period) — so that part of the physics needed no change,
    only cleanup once the beam FRF genuinely has no Omega argument left.

Because the beam/absorber dynamics no longer depend on spindle speed,
every place that used to sweep 3-5 spindle speeds per design (inner GA
tuning, outer-GA stability evaluation, absorber-clearance check) now
needs only ONE frequency-response solve per design — a straightforward
simplification that also makes the GA noticeably faster.

Outer GA: NSGA-II (Deb et al. 2002), 6 design variables
  x = [D_cav, L_cav, D_abs, L_abs, Z_TIP, D_body_in]
  Objectives: max alim, max static stiffness, min mass
Inner GA: single-objective GA tunes [kd, cd] per outer individual.
==========================================================================
"""

import numpy as np
from scipy.optimize import minimize_scalar  # kept for parity with original toolchain
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import warnings; warnings.filterwarnings('ignore')

plt.rcParams.update({'font.size':9,'axes.titlesize':9,'axes.labelsize':8.5,
                     'xtick.labelsize':8,'ytick.labelsize':8,
                     'legend.fontsize':7,'figure.dpi':150})
# Out:
# ================================================================
# STATIC Boring Bar GA  —  tool stationary, workpiece rotating
# Outer NSGA-II + Inner GA  (6-variable design space)
# ================================================================
#   Outer GA:  pop=40  gen=20  SBX ηc=15.0  poly-mut ηm=20.0
#   Inner GA:  pop=10  gen=10
#   Variables: D_cav, L_cav, D_abs, L_abs, Z_TIP, D_body_in
#   Objectives: alim↑ K↑ m↓
#   Constraint: V_abs ≤ 70% V_cav  |  D_abs≤D_cav  L_abs≤L_cav  |  wall≥3mm (cavity AND body bore)
#   Rotordynamics: NONE on the bar (bar does not rotate).
#   Chatter mechanism: classical regenerative chatter driven by
#                       WORKPIECE rotation (phase delay T=60/RPM).
# ================================================================

# %%
# ══════════════════════════════════════════════════════════════
# 1. FIXED PARAMETERS
# ══════════════════════════════════════════════════════════════
E_body   = 280e9
rho_body = 7850.0 * 1.2    # 9420 kg/m3  (WC-equivalent effective density)
rho_tc   = 15600.0
zeta_s   = 0.01             # structural damping ratio (oil damping not included)

L_total = 0.300; D1_out = 0.060; D_main = 0.040
L1 = 0.050; L2 = 0.040; L5_tip_min = 0.030   # L5_tip_min: minimum solid tip length

Nt=1; Ktc=2000e6; Krc=800e6; ratio_kr=Krc/Ktc
N_ELEM=60; N_MODES=6

D_cav_min, D_cav_max = 0.010, D_main - 2*0.003   # 10-34 mm (3mm min wall, Sec4)
L_cav_min, L_cav_max = 0.020, 0.170
VOL_FRAC_MAX = 0.70

# ── Design variables ────────────────────────────────────────────
Z_TIP_min, Z_TIP_max     = L5_tip_min, 0.150       # 30-150 mm from free end
D_body_in_min            = 0.010                    # 10 mm minimum bore
D_body_in_max            = D_main - 2*0.003         # 34 mm (3mm wall under D_main)

# ── GA hyper-parameters ───────────────────────────────────────
GA_OUTER_POP   = 40
GA_OUTER_NGEN  = 20
GA_OUTER_PC    = 0.90
GA_OUTER_PM    = 1/6    # 1/n_vars, n_vars = 6
GA_OUTER_ETA_C = 15.0
GA_OUTER_ETA_M = 20.0

GA_INNER_POP   = 10
GA_INNER_NGEN  = 10
GA_INNER_PC    = 0.90
GA_INNER_PM    = 1/2
GA_INNER_ETA_C = 10.0
GA_INNER_ETA_M = 15.0

LOG_KD_MIN, LOG_KD_MAX = 4.0, 6.0
LOG_CD_MIN, LOG_CD_MAX = 0.0, 4.5

print("="*64)
print("STATIC Boring Bar GA  —  tool stationary, workpiece rotating")
print("Outer NSGA-II + Inner GA  (6-variable design space)")
print("="*64)
print(f"  Outer GA:  pop={GA_OUTER_POP}  gen={GA_OUTER_NGEN}  "
      f"SBX \u03b7c={GA_OUTER_ETA_C}  poly-mut \u03b7m={GA_OUTER_ETA_M}")
print(f"  Inner GA:  pop={GA_INNER_POP}  gen={GA_INNER_NGEN}")
print(f"  Variables: D_cav, L_cav, D_abs, L_abs, Z_TIP, D_body_in")
print(f"  Objectives: alim\u2191 K\u2191 m\u2193")
print(f"  Constraint: V_abs \u2264 {VOL_FRAC_MAX*100:.0f}% V_cav  |  "
      f"D_abs\u2264D_cav  L_abs\u2264L_cav  |  wall\u22653mm (cavity AND body bore)")
print(f"  Rotordynamics: NONE on the bar (bar does not rotate).")
print(f"  Chatter mechanism: classical regenerative chatter driven by")
print(f"                      WORKPIECE rotation (phase delay T=60/RPM).")
print("="*64)

# %%
# ══════════════════════════════════════════════════════════════
# 2. CROSS-SECTION  (geometry is unaffected by the rotation
#    assumption — identical to the rotary-bar reference)
# ══════════════════════════════════════════════════════════════
def xsec(z, D_cav, L_cav, Z_TIP, D_body_in):
    """
    5-section cross-section:

      Sec1 [0, L1]            : hollow, D_out=D1_out,  D_in=D_body_in
      Sec2 [L1, L1+L2]        : hollow, D_out tapers D1_out->D_main,
                                 D_in = D_body_in (CONSTANT, not tapered)
      Sec3 [L1+L2, z_cav]     : hollow, D_out=D_main,  D_in=D_body_in
      Sec4 [z_cav, z_cav+L_cav]: hollow, D_out=D_main, D_in=D_cav (absorber cavity)
      Sec5 [z_cav+L_cav, L]   : solid,  D_out=D_main

    z_cav = L_total - Z_TIP - L_cav
    """
    z_cav = L_total - Z_TIP - L_cav
    z2 = L1+L2; z4 = z_cav+L_cav
    if   z < L1:  Ro = D1_out/2
    elif z < z2:  Ro = D1_out/2 + (z-L1)/L2*(D_main-D1_out)/2
    else:         Ro = D_main/2
    if z < z_cav:
        Ri = D_body_in/2          # constant bore through Sec1, Sec2, Sec3
    elif z < z4:
        Ri = D_cav/2              # absorber cavity bore
    else:
        Ri = 0.0                  # solid tip (Sec5)
    Ri = np.clip(Ri, 0.0, Ro-1e-4)
    A  = np.pi*(Ro**2 - Ri**2)
    I  = np.pi*(Ro**4 - Ri**4)/4
    return A, I, rho_body*A, rho_body*I

# %%
# ══════════════════════════════════════════════════════════════
# 3. FEM  —  build_MK returns Mf, Kf ONLY.
#
#    A rotary bar needed a gyroscopic kernel Gf (rho*Ip weighted) and a
#    translational-only mass kernel Ma (rho*A weighted) to build the
#    rotation-induced coupling and centrifugal-softening terms. A
#    STATIC bar has neither effect (Omega_bar = 0 always), so those two
#    matrices are simply never assembled here — one less FEM pass per
#    design evaluation.
# ══════════════════════════════════════════════════════════════
gp = np.array([-np.sqrt(3/5), 0.0, np.sqrt(3/5)])
gw = np.array([5/9, 8/9, 5/9])

def build_MK(D_cav, L_cav, Z_TIP, D_body_in):
    ne=N_ELEM; nn=ne+1; le=L_total/ne
    zn=np.linspace(0,L_total,nn); dof=2*nn
    Mg=np.zeros((dof,dof)); Kg=np.zeros((dof,dof))
    for e in range(ne):
        za=zn[e]
        Ke=np.zeros((4,4)); Me=np.zeros((4,4))
        for g,w in zip(gp,gw):
            xi=(g+1)/2; zg=za+xi*le
            _, Ig, rhoAg, rhoIg = xsec(zg, D_cav, L_cav, Z_TIP, D_body_in)
            N1=1-3*xi**2+2*xi**3;  N2=le*(xi-2*xi**2+xi**3)
            N3=3*xi**2-2*xi**3;    N4=le*(-xi**2+xi**3)
            dN1=(-6*xi+6*xi**2)/le;  dN2=1-4*xi+3*xi**2
            dN3=(6*xi-6*xi**2)/le;   dN4=-2*xi+3*xi**2
            d2N1=(-6+12*xi)/le**2;   d2N2=(-4+6*xi)/le
            d2N3=(6-12*xi)/le**2;    d2N4=(-2+6*xi)/le
            Nv  = np.array([N1,N2,N3,N4])
            dN_ = np.array([dN1,dN2,dN3,dN4])
            d2N = np.array([d2N1,d2N2,d2N3,d2N4])
            fac = le*w/2

            # Stiffness
            Ke += E_body*Ig*np.outer(d2N,d2N)*fac
            # Full mass: translational (rho*A) + rotary inertia (rho*I)
            Me += (rhoAg*np.outer(Nv,Nv) + rhoIg*np.outer(dN_,dN_))*fac

        idx=[2*e,2*e+1,2*(e+1),2*(e+1)+1]
        for i,ii in enumerate(idx):
            for j,jj in enumerate(idx):
                Mg[ii,jj]  += Me[i,j]
                Kg[ii,jj]  += Ke[i,j]

    free=list(range(2,dof)); sl=np.ix_(free,free)
    return Mg[sl], Kg[sl]

# %%
# ══════════════════════════════════════════════════════════════
# 4. MODAL REDUCTION  (no Gm/Mam — nothing rotation-induced to project)
# ══════════════════════════════════════════════════════════════
def modal_reduce(D_cav, L_cav, Z_TIP, D_body_in):
    from scipy.linalg import eigh
    Mf, Kf = build_MK(D_cav, L_cav, Z_TIP, D_body_in)
    evals,evecs   = eigh(Kf, Mf, subset_by_index=[0,N_MODES-1])
    wn  = np.sqrt(np.maximum(evals, 0))
    sc  = np.sqrt(np.diag(evecs.T @ Mf @ evecs))
    Phi = evecs / sc

    return dict(wn=wn, Phi=Phi,
                tip=Phi[2*(N_ELEM-1),:], Cm=2*zeta_s*wn,
                Mf=Mf, Kf=Kf)

# %%
# ══════════════════════════════════════════════════════════════
# 5. ABSORBER PARAMETERS  (unchanged — geometry only)
# ══════════════════════════════════════════════════════════════
def absorber_params(D_cav, L_cav, D_abs, L_abs, Z_TIP):
    md    = rho_tc * np.pi*(D_abs/2)**2 * L_abs
    z_cav = L_total - Z_TIP - L_cav
    z_d   = z_cav + L_cav/2
    return md, z_d

def vol_fraction(D_cav, L_cav, D_abs, L_abs):
    V_abs = np.pi*(D_abs/2)**2 * L_abs
    V_cav = np.pi*(D_cav/2)**2 * L_cav
    return V_abs / (V_cav + 1e-20)

# %%
# ══════════════════════════════════════════════════════════════
# 6. MODAL FRF  —  STATIC bar, no rotation-induced coupling
#
#    Beam equations of motion, modal coordinates q_x (length N_MODES):
#
#      q_ddot_x + Cm*q_dot_x + diag(wn^2)*q_x = f_x     (x-plane)
#      q_ddot_y + Cm*q_dot_y + diag(wn^2)*q_y = f_y     (y-plane)
#
#    x and y are UNCOUPLED (no gyroscopic/Coriolis term exists, because
#    the bar never rotates about its own axis) and, for an axisymmetric
#    cross-section, identical: Hyy(w) == Hxx(w), Hyx(w) == Hxy(w) == 0.
#    So only ONE (N_MODES [+1 absorber]) - dof complex system needs to
#    be solved per frequency, not the 2N(+2)-dof coupled system a
#    rotary bar requires. Hxy is still returned (as an all-zero array)
#    purely so alim_from_FRF()'s general 2-D directional-coefficient
#    formula (Sec. 7-8, unchanged from the rotary case) can be reused
#    without modification.
# ══════════════════════════════════════════════════════════════
def _assemble_Z_static(w, wn, Cm_d, N, kd, cd, Phi_d, md, use_abs):
    na = N+1 if use_abs else N
    Z = np.zeros((na, na), dtype=complex)
    w2 = w**2
    for r in range(N):
        Z[r, r] = -w2 + 1j*w*Cm_d[r] + wn[r]**2
    if use_abs:
        for r in range(N):
            c = (kd + 1j*w*cd)*Phi_d[r]
            Z[r, r] += Phi_d[r]*c
            Z[r, N] -= c
            Z[N, r] -= c
        Z[N, N] = -w2*md + kd + 1j*w*cd
    return Z


def frf(modal, freqs_hz, D_cav, L_cav, D_abs, L_abs, Z_TIP, kd=0.0, cd=0.0):
    N=N_MODES; wn=modal['wn']; tip=modal['tip']; Cm_d=modal['Cm']

    md, z_d = absorber_params(D_cav, L_cav, D_abs, L_abs, Z_TIP)
    nd  = int(round(z_d/L_total*N_ELEM)); nd=min(nd,N_ELEM)
    iab = min(2*(nd-1) if nd>0 else 0, modal['Phi'].shape[0]-1)
    Phi_d = modal['Phi'][iab,:]

    use_abs = (kd>0); na = N+1 if use_abs else N
    Hxx=np.zeros(len(freqs_hz),dtype=complex)

    for k,f in enumerate(freqs_hz):
        w=2*np.pi*f
        Z = _assemble_Z_static(w, wn, Cm_d, N, kd, cd, Phi_d, md, use_abs)
        fx=np.zeros(na,dtype=complex); fx[:N]=tip
        try:
            sol=np.linalg.solve(Z, fx)
            Hxx[k]=tip@sol[:N]
        except: pass

    Hxy = np.zeros(len(freqs_hz), dtype=complex)   # stationary axisymmetric bar: no cross-FRF
    return Hxx, Hxy

# %%
# ══════════════════════════════════════════════════════════════
# 7. DIRECTIONAL COEFFICIENTS  (unchanged — these come from the
#    orthogonal-cutting force geometry of a boring operation, not
#    from any structural rotation of the bar)
# ══════════════════════════════════════════════════════════════
_phi = np.linspace(0,2*np.pi,100000)
axx_b=np.trapezoid(np.sin(_phi)*(-np.cos(_phi)-ratio_kr*np.sin(_phi)),_phi)/(2*np.pi)
axy_b=np.trapezoid(np.cos(_phi)*(-np.cos(_phi)-ratio_kr*np.sin(_phi)),_phi)/(2*np.pi)
ayx_b=np.trapezoid(np.sin(_phi)*( np.sin(_phi)-ratio_kr*np.cos(_phi)),_phi)/(2*np.pi)
ayy_b=np.trapezoid(np.cos(_phi)*( np.sin(_phi)-ratio_kr*np.cos(_phi)),_phi)/(2*np.pi)

# %%
# ══════════════════════════════════════════════════════════════
# 8. STABILITY LIMIT (asymptotic, all chatter frequencies) — unchanged
#    algebra; Hxy is now identically zero, which the formula handles
#    correctly (h12/h21 reduce to axy_b*Hxx / ayx_b*Hxx automatically).
# ══════════════════════════════════════════════════════════════
def alim_from_FRF(Hxx, Hxy):
    best = np.inf
    for k in range(len(Hxx)):
        Hyy=Hxx[k]; Hyx=Hxy[k]
        h11=axx_b*Hxx[k]+axy_b*Hyx; h12=axx_b*Hxy[k]+axy_b*Hyy
        h21=ayx_b*Hxx[k]+ayy_b*Hyx; h22=ayx_b*Hxy[k]+ayy_b*Hyy
        tr=h11+h22; det=h11*h22-h12*h21
        if abs(det)<1e-28: continue
        sq=np.sqrt(tr**2-4*det+0j)
        for lam in [(-tr+sq)/(2*det), (-tr-sq)/(2*det)]:
            rl=np.real(lam)
            if rl<0:
                kap=np.imag(lam)/(rl+1e-30)
                al=(-2*np.pi*rl/(Nt*Ktc))*(1+kap**2)
                if 0<al<best: best=al
    return min(best,0.005) if best<np.inf else 0.0

# %%
# ══════════════════════════════════════════════════════════════
# 9. STATIC STIFFNESS + TOTAL MASS  (unchanged)
# ══════════════════════════════════════════════════════════════
def static_stiff(Kf):
    tip_dof   = 2*(N_ELEM-1)
    fv = np.zeros(Kf.shape[0]); fv[tip_dof] = 1.0
    return 1.0 / np.linalg.solve(Kf, fv)[tip_dof]

def total_mass(D_cav, L_cav, D_abs, L_abs, Z_TIP, D_body_in):
    z_cav = L_total - Z_TIP - L_cav
    z2 = L1 + L2
    z4 = z_cav + L_cav

    zz = np.linspace(0, L_total, 2001)
    zm = (zz[:-1] + zz[1:]) / 2.0
    dz = L_total / 2000

    Ro = np.where(zm < L1, D1_out/2,
         np.where(zm < z2, D1_out/2 + (zm-L1)/L2*(D_main-D1_out)/2, D_main/2))
    Ri = np.where(zm < z_cav, D_body_in/2,
         np.where(zm < z4, D_cav/2, 0.0))
    Ri = np.clip(Ri, 0.0, Ro - 1e-4)

    A  = np.pi*(Ro**2 - Ri**2)
    mb = np.sum(rho_body*A*dz)

    md,_ = absorber_params(D_cav, L_cav, D_abs, L_abs, Z_TIP)
    return mb + md

# %%
# ══════════════════════════════════════════════════════════════
# 10. STABILITY LOBE DIAGRAM  (workpiece-RPM driven regeneration)
#
#     Physics reminder: the bar's FRF (Hxx, Hxy) does NOT depend on
#     spindle speed in the static-bar case — it is evaluated once.
#     Workpiece RPM enters ONLY through the regeneration phase delay
#     T = 60/RPM below (classical Tobias/Altintas turning stability
#     lobe construction). This is unchanged from — indeed, it is
#     exactly the same algebra as — the rotary-bar reference, which
#     already evaluated this part at Omega=0.
# ══════════════════════════════════════════════════════════════
def compute_stability_lobes_by_mode(modal, D_cav, L_cav, D_abs, L_abs, Z_TIP,
                                     kd, cd, rpm_max=6000, n_lobes=8,
                                     n_freq=1500, f_margin=1.4):
    """
    Mode-resolved regenerative-chatter stability lobe calculation.

    Returns
    -------
    dict with:
      'fn_hz'        : (N_MODES,) array — retained structural natural
                        frequencies [Hz], used as the mode labels/colours.
      'lobes'        : nested dict {mode_idx: {lobe_order: {'rpm':arr,'depth':arr}}}
                        each (rpm, depth) pair already sorted by rpm.
      'a_lim_crit'   : float [mm] — absolute/asymptotic stability limit
                        (minimum stable depth across all speeds & lobes).
      'freqs_used'   : the chatter-frequency grid actually evaluated [Hz].
    """
    fn_hz = modal['wn'] / (2*np.pi)
    f_lo = max(5.0, 0.5*np.min(fn_hz))
    f_hi = f_margin * np.max(fn_hz)
    freqs_c = np.linspace(f_lo, f_hi, n_freq)

    Hxx, Hxy = frf(modal, freqs_c, D_cav, L_cav, D_abs, L_abs, Z_TIP, kd, cd)

    raw = {}
    a_lim_crit_m = np.inf

    for k, fc in enumerate(freqs_c):
        Hyy = Hxx[k]; Hyx = Hxy[k]
        h11 = axx_b*Hxx[k] + axy_b*Hyx; h12 = axx_b*Hxy[k] + axy_b*Hyy
        h21 = ayx_b*Hxx[k] + ayy_b*Hyx; h22 = ayx_b*Hxy[k] + ayy_b*Hyy
        tr = h11 + h22; det = h11*h22 - h12*h21
        if abs(det) < 1e-28:
            continue
        sq = np.sqrt(tr**2 - 4*det + 0j)
        for lam in [(-tr+sq)/(2*det), (-tr-sq)/(2*det)]:
            rl = np.real(lam); il = np.imag(lam)
            if rl >= 0:
                continue
            kap = il/(rl + 1e-30)
            al = (-2*np.pi*rl/(Nt*Ktc)) * (1 + kap**2)
            if al <= 0 or al > 25:
                continue
            a_lim_crit_m = min(a_lim_crit_m, al)

            mode_idx = int(np.argmin(np.abs(fn_hz - fc)))

            psi = np.arctan2(il, rl)
            for n in range(n_lobes):
                eps = np.pi - 2*psi if psi < 0 else -(np.pi + 2*psi)
                T = (eps + 2*np.pi*n) / (2*np.pi*fc)
                if T <= 0:
                    continue
                rpm = 60/T
                if 0 < rpm <= rpm_max:
                    raw.setdefault((mode_idx, n), []).append((rpm, al*1e3))

    lobes = {i: {} for i in range(len(fn_hz))}
    for (mode_idx, n), pts in raw.items():
        pts = np.array(pts)
        order = np.argsort(pts[:, 0])
        lobes[mode_idx][n] = dict(rpm=pts[order, 0], depth=pts[order, 1])

    a_lim_crit = a_lim_crit_m*1e3 if np.isfinite(a_lim_crit_m) else np.nan

    return dict(fn_hz=fn_hz, lobes=lobes, a_lim_crit=a_lim_crit,
                freqs_used=freqs_c)

def compute_lower_envelope(lobes, rpm_max=6000, n_grid=2000):
    """
    Lower envelope of the SLD: for each workpiece speed, the minimum
    stable depth of cut across ALL structural modes and ALL lobe orders.
    """
    rpm_grid = np.linspace(0, rpm_max, n_grid)
    env_depth = np.full(n_grid, np.inf)

    for mode_idx, mode_lobes in lobes.items():
        for n, d in mode_lobes.items():
            rpm_pts, depth_pts = d['rpm'], d['depth']
            if len(rpm_pts) < 2:
                continue
            order = np.argsort(rpm_pts)
            rpm_s, depth_s = rpm_pts[order], depth_pts[order]
            in_range = (rpm_grid >= rpm_s[0]) & (rpm_grid <= rpm_s[-1])
            if not np.any(in_range):
                continue
            interp_depth = np.interp(rpm_grid[in_range], rpm_s, depth_s)
            env_depth[in_range] = np.minimum(env_depth[in_range], interp_depth)

    return rpm_grid, env_depth

def plot_stability_lobe_diagram(modal, D_cav, L_cav, D_abs, L_abs, Z_TIP,
                                 kd, cd, rpm_max=6000, n_lobes=25, ax=None,
                                 title=None, max_depth_mm=25.0):
    """
    Draw a mode-resolved stability lobe diagram on `ax` vs WORKPIECE RPM.
    """
    res = compute_stability_lobes_by_mode(modal, D_cav, L_cav, D_abs, L_abs,
                                           Z_TIP, kd, cd, rpm_max=rpm_max,
                                           n_lobes=n_lobes)
    fn_hz, lobes, a_lim_crit = res['fn_hz'], res['lobes'], res['a_lim_crit']

    if ax is None:
        fig, ax = plt.subplots(figsize=(8, 5.5))

    cmap = plt.get_cmap('tab10')
    any_plotted = False
    for mode_idx in sorted(lobes.keys()):
        mode_lobes = lobes[mode_idx]
        if not mode_lobes:
            continue
        color = cmap(mode_idx % 10)
        for n in sorted(mode_lobes.keys()):
            d = mode_lobes[n]
            if len(d['rpm']) < 2:
                continue
            lw = max(0.6, 1.8 - 0.18*n)
            alpha = max(0.35, 0.95 - 0.08*n)
            ax.plot(d['rpm'], d['depth'], color=color, lw=lw, alpha=alpha)
            any_plotted = True
        ax.plot([], [], color=color, lw=1.8,
                 label=f'Mode {mode_idx+1}  f_n={fn_hz[mode_idx]:.0f} Hz')

    if np.isfinite(a_lim_crit):
        ax.axhline(a_lim_crit, color='k', ls='--', lw=1.2,
                    label=f'Absolute stability limit  a_lim={a_lim_crit:.2f} mm')
    rpm_env, depth_env = compute_lower_envelope(lobes, rpm_max=rpm_max)
    finite_env = np.isfinite(depth_env)
    if np.any(finite_env):
        ax.plot(rpm_env[finite_env], depth_env[finite_env],
                 color='red', lw=2.2, ls='-', alpha=0.9, zorder=6,
                 label='Lower envelope (speed-dependent limit)')
    if not any_plotted:
        ax.text(0.5, 0.5, 'No stable lobes found in range',
                transform=ax.transAxes, ha='center', va='center', fontsize=10)

    ax.set_xlim(0, rpm_max)
    ax.set_ylim(0, max_depth_mm)
    ax.set_xlabel('Workpiece spindle speed [RPM]')
    ax.set_ylabel('Axial depth of cut a_lim [mm]')
    ax.set_title(title or 'Stability lobe diagram — by structural mode')
    ax.legend(fontsize=7.5, loc='upper right', ncol=1)
    ax.grid(True, alpha=0.3)
    res['rpm_env'], res['depth_env'] = rpm_env, depth_env
    return ax, res

# %%
# ══════════════════════════════════════════════════════════════
# 10.5  ABSORBER-HOLDER RELATIVE DISPLACEMENT & COLLISION CHECK
#
#       Speed-independent now: with no rotation-induced coupling, the
#       absorber's relative motion inside its cavity does not depend
#       on workpiece RPM either (RPM only shows up in the regeneration
#       phase used for the SLD, Sec. 10) — so the old clearance_vs_speed()
#       sweep (which existed to catch worst-case Coriolis/centrifugal
#       growth at high bar-rotation speed) is not physically meaningful
#       here and has been removed. One static evaluation is enough.
# ══════════════════════════════════════════════════════════════
A_P_ASSUMED = 0.001     # m   assumed depth of cut  (1 mm)
F_ASSUMED   = 0.0001    # m   assumed feed per rev   (0.1 mm/rev)
F_REP_DEFAULT = Ktc * A_P_ASSUMED * F_ASSUMED   # N, representative cutting force

_FREQS_CLEARANCE = np.linspace(10, 800, 200)


def relative_displacement_FRF(modal, freqs_hz, D_cav, L_cav,
                              D_abs, L_abs, Z_TIP, kd, cd):
    """
    Relative-displacement transfer function H_rel(w) between the beam
    (at the absorber's axial location z_d) and the absorber mass, per
    unit tip force. Single-plane only: with no rotation-induced
    coupling, a unit force in x never produces any y-plane response,
    so the y-plane relative displacement that a rotary bar would show
    is identically zero here and is not computed.

    Requires kd > 0 (absorber must be present).
    """
    if kd <= 0:
        raise ValueError("relative_displacement_FRF requires kd > 0 "
                         "(absorber must be present)")

    N=N_MODES; wn=modal['wn']; tip=modal['tip']; Cm_d = modal['Cm']

    md, z_d = absorber_params(D_cav, L_cav, D_abs, L_abs, Z_TIP)
    nd  = int(round(z_d/L_total*N_ELEM)); nd=min(nd,N_ELEM)
    iab = min(2*(nd-1) if nd>0 else 0, modal['Phi'].shape[0]-1)
    Phi_d = modal['Phi'][iab,:]

    na = N+1
    Hrel = np.zeros(len(freqs_hz), dtype=complex)

    for k, f in enumerate(freqs_hz):
        w = 2*np.pi*f
        Z = _assemble_Z_static(w, wn, Cm_d, N, kd, cd, Phi_d, md, True)
        fx = np.zeros(na, dtype=complex); fx[:N] = tip
        try:
            sol = np.linalg.solve(Z, fx)
            u_beam_at_d = Phi_d @ sol[:N]
            u_abs       = sol[N]
            Hrel[k] = u_beam_at_d - u_abs
        except:
            pass
    return Hrel


def check_absorber_clearance(modal, D_cav, L_cav, D_abs, L_abs, Z_TIP, kd, cd,
                             F_rep=None):
    """
    Static (RPM-independent) clearance check.

    Returns
    -------
    dict with:
      delta_gap      : m,  radial clearance = (D_cav - D_abs)/2
      delta_rel_max  : m,  max relative displacement over freq range,
                            scaled by F_rep
      f_at_max       : Hz, frequency at which delta_rel_max occurs
      clearance_ratio: delta_rel_max / delta_gap  (>=1 means collision)
      collision      : bool, True if clearance_ratio >= 1
    """
    if F_rep is None:
        F_rep = F_REP_DEFAULT

    delta_gap = (D_cav - D_abs) / 2.0
    if delta_gap <= 0:
        return dict(delta_gap=0.0, delta_rel_max=np.inf, f_at_max=0.0,
                    clearance_ratio=np.inf, collision=True)

    Hrel = relative_displacement_FRF(
        modal, _FREQS_CLEARANCE, D_cav, L_cav, D_abs, L_abs, Z_TIP, kd, cd)
    delta_rel = F_rep * np.abs(Hrel)

    i_max = int(np.argmax(delta_rel))
    delta_rel_max = float(delta_rel[i_max])
    f_at_max      = float(_FREQS_CLEARANCE[i_max])
    ratio         = delta_rel_max / delta_gap

    return dict(delta_gap=delta_gap, delta_rel_max=delta_rel_max,
                f_at_max=f_at_max, clearance_ratio=ratio,
                collision=(ratio >= 1.0))

# %%
# ══════════════════════════════════════════════════════════════
# 11. SHARED GA OPERATORS  (unchanged — pure numerics, no physics)
# ══════════════════════════════════════════════════════════════

def sbx_crossover(p1, p2, bounds, eta_c, p_cross, rng):
    """Simulated Binary Crossover (SBX) — Deb & Agrawal 1995."""
    n    = len(p1)
    c1   = p1.copy(); c2 = p2.copy()
    lo   = bounds[:,0]; hi = bounds[:,1]
    if rng.random() > p_cross:
        return c1, c2
    for i in range(n):
        y1 = min(p1[i], p2[i]); y2 = max(p1[i], p2[i])
        if (y2 - y1) < 1e-14:
            continue
        u   = rng.random()
        beta = 1.0 + 2.0*min(y1 - lo[i], hi[i] - y2) / (y2 - y1)
        alpha = 2.0 - beta**(-(eta_c+1.0))
        if u <= 1.0/alpha:
            betaq = (u*alpha)**(1.0/(eta_c+1.0))
        else:
            betaq = (1.0/(2.0 - u*alpha))**(1.0/(eta_c+1.0))
        c1[i] = 0.5*(y1+y2) - 0.5*betaq*(y2-y1)
        c2[i] = 0.5*(y1+y2) + 0.5*betaq*(y2-y1)
    c1 = np.clip(c1, lo, hi); c2 = np.clip(c2, lo, hi)
    return c1, c2


def polynomial_mutation(x, bounds, eta_m, p_mut, rng):
    """Polynomial Mutation — Deb & Goyal 1996."""
    x_mut = x.copy()
    lo    = bounds[:,0]; hi = bounds[:,1]
    for i in range(len(x)):
        if rng.random() > p_mut:
            continue
        u  = rng.random()
        d  = min(x[i]-lo[i], hi[i]-x[i]) / max(hi[i]-lo[i], 1e-14)
        if u < 0.5:
            deltaq = (2.0*u + (1.0-2.0*u)*(1.0-d)**(eta_m+1))**(1.0/(eta_m+1)) - 1.0
        else:
            deltaq = 1.0 - (2.0*(1.0-u) + 2.0*(u-0.5)*(1.0-d)**(eta_m+1))**(1.0/(eta_m+1))
        x_mut[i] = np.clip(x[i] + deltaq*(hi[i]-lo[i]), lo[i], hi[i])
    return x_mut


def tournament_select(pop, fitness, rng, k=2):
    """Binary tournament selection (lower fitness wins)."""
    idx = rng.choice(len(pop), size=k, replace=False)
    winner = idx[np.argmin(fitness[idx])]
    return pop[winner].copy()

# %%
# ══════════════════════════════════════════════════════════════
# 12. INNER GA — optimise kd and cd
#
#     Simplification vs. the rotary-bar reference: since the beam FRF
#     no longer depends on spindle speed, tuning the absorber against
#     "the worst of 3 speeds" (0/3000/6000 RPM) is unnecessary — one
#     alim evaluation per candidate [kd,cd] is now sufficient and exact.
# ══════════════════════════════════════════════════════════════
_FREQS_INNER = np.linspace(10, 800, 100)
_BOUNDS_INNER = np.array([[LOG_KD_MIN, LOG_KD_MAX],
                           [LOG_CD_MIN, LOG_CD_MAX]])

def _inner_fitness(lkd, lcd, modal, D_cav, L_cav, D_abs, L_abs, Z_TIP, b_val):
    kd_ = 10**lkd; cd_ = 10**lcd
    Ha, Hxa = frf(modal, _FREQS_INNER, D_cav, L_cav, D_abs, L_abs, Z_TIP, kd_, cd_)
    a = alim_from_FRF(Ha, Hxa)
    return -max(min(a, b_val*50.0), b_val)


def inner_GA_tune_kd_cd(modal, D_cav, L_cav, D_abs, L_abs, Z_TIP, rng):
    """Inner GA: evolve [log10(kd), log10(cd)] to maximise alim."""
    md, _ = absorber_params(D_cav, L_cav, D_abs, L_abs, Z_TIP)
    wn1   = modal['wn'][0]
    mu    = max(md / (rho_body*np.pi*(D_main/2)**2*L_total), 0.005)
    wd    = wn1/(1+mu)
    kd_dh = md*wd**2
    cd_dh = 2*np.sqrt(3*mu/(8*(1+mu)**3))*md*wd
    lkd_dh = np.log10(max(kd_dh, 10**LOG_KD_MIN))
    lcd_dh = np.log10(max(cd_dh, 10**LOG_CD_MIN))

    n_pop  = GA_INNER_POP
    n_half = n_pop // 2
    bounds = _BOUNDS_INNER
    lo = bounds[:,0]; hi = bounds[:,1]

    # Bare-bar (kd=cd=0) alim, computed once — no speed sweep needed.
    Hb, Hxb = frf(modal, _FREQS_INNER, D_cav, L_cav, D_abs, L_abs, Z_TIP, 0.0, 0.0)
    b_val = alim_from_FRF(Hb, Hxb)

    pop = np.zeros((n_pop, 2))
    pop[:n_half, 0] = np.clip(lkd_dh + rng.normal(0, 0.3, n_half), lo[0], hi[0])
    pop[:n_half, 1] = np.clip(lcd_dh + rng.normal(0, 0.3, n_half), lo[1], hi[1])  # warm start
    pop[n_half:, 0] = rng.uniform(lo[0], hi[0], n_pop-n_half)
    pop[n_half:, 1] = rng.uniform(lo[1], hi[1], n_pop-n_half)

    fit = np.array([_inner_fitness(p[0],p[1], modal, D_cav, L_cav, D_abs, L_abs, Z_TIP, b_val)
                    for p in pop])

    for _gen in range(GA_INNER_NGEN):
        new_pop = np.zeros_like(pop)
        i_elite = np.argmin(fit)
        new_pop[0] = pop[i_elite]
        child_idx = 1
        while child_idx < n_pop:
            p1 = tournament_select(pop, fit, rng)
            p2 = tournament_select(pop, fit, rng)
            c1, c2 = sbx_crossover(p1, p2, bounds, GA_INNER_ETA_C, GA_INNER_PC, rng)
            c1 = polynomial_mutation(c1, bounds, GA_INNER_ETA_M, GA_INNER_PM, rng)
            c2 = polynomial_mutation(c2, bounds, GA_INNER_ETA_M, GA_INNER_PM, rng)
            new_pop[child_idx] = c1
            if child_idx+1 < n_pop:
                new_pop[child_idx+1] = c2
            child_idx += 2
        pop = new_pop
        fit = np.array([_inner_fitness(p[0],p[1], modal, D_cav, L_cav, D_abs, L_abs, Z_TIP, b_val)
                        for p in pop])

    i_best_inner = np.argmin(fit)
    return 10**pop[i_best_inner, 0], 10**pop[i_best_inner, 1]

# %%
# ══════════════════════════════════════════════════════════════
# 13. FEASIBILITY CHECK + CONSTRAINT REPAIR  (unchanged — geometry
#     constraints are independent of the rotation assumption)
# ══════════════════════════════════════════════════════════════
_BOUNDS_OUTER = np.array([
    [D_cav_min,      D_cav_max],       # D_cav
    [L_cav_min,      L_cav_max],       # L_cav
    [0.005,          D_cav_max-0.001], # D_abs  (<= D_cav enforced in repair)
    [0.005,          L_cav_max-0.001], # L_abs  (<= L_cav enforced in repair)
    [Z_TIP_min,      Z_TIP_max],       # Z_TIP
    [D_body_in_min,  D_body_in_max],   # D_body_in
])

def repair_and_check(x):
    """
    Repairs a 6-gene chromosome in place and returns it, or None if
    no feasible repair exists.

    Repair order (each step only tightens what the previous steps set):
      1. Clip all 6 genes to their box bounds.
      2. Enforce minimum solid tip: Z_TIP >= L5_tip_min.
      3. Enforce z_cav >= L1+L2+5mm by shortening L_cav if necessary.
      4. Enforce D_abs <= D_cav, L_abs <= L_cav.
      5. Enforce V_abs <= VOL_FRAC_MAX * V_cav by shortening L_abs.
      6. Enforce D_body_in <= D_cav.
      7. Reject (return None) if any dimension collapses below a
         practical minimum after repair.
    """
    x = np.clip(x, _BOUNDS_OUTER[:,0], _BOUNDS_OUTER[:,1])
    D_cav, L_cav, D_abs, L_abs, Z_TIP, D_body_in = x

    if Z_TIP < L5_tip_min:
        Z_TIP = L5_tip_min
        x[4] = Z_TIP

    z_cav = L_total - Z_TIP - L_cav
    if z_cav < L1+L2+0.005:
        L_cav = L_total - Z_TIP - (L1+L2+0.005)
        if L_cav < L_cav_min:
            return None
        x[1] = L_cav

    D_abs = min(D_abs, D_cav); x[2] = D_abs
    L_abs = min(L_abs, L_cav); x[3] = L_abs

    V_cav = np.pi*(D_cav/2)**2 * L_cav
    V_abs = np.pi*(D_abs/2)**2 * L_abs
    if V_abs > VOL_FRAC_MAX * V_cav:
        L_abs = VOL_FRAC_MAX * (D_cav/D_abs)**2 * L_cav
        L_abs = min(L_abs, L_cav)
        x[3]  = L_abs

    if D_body_in > D_cav:
        D_body_in = D_cav
        x[5] = D_body_in

    if D_abs < 0.005 or L_abs < 0.005:
        return None
    if D_body_in < D_body_in_min*0.5:
        return None

    return x

# %%
# ══════════════════════════════════════════════════════════════
# 14. OUTER GA INDIVIDUAL EVALUATION
#
#     Simplification vs. the rotary-bar reference: alim is no longer
#     averaged over a 0-6000 RPM sweep of the BAR's own rotation (that
#     sweep existed only because a rotary bar's FRF changes with its
#     own Omega). Here alim is computed from a single static FRF
#     solve, both with the tuned absorber and bare. Workpiece RPM still
#     matters for the stability-lobe plot (Sec. 10) shown after
#     optimisation, just not for this per-individual scalar objective
#     (a_lim_crit, the asymptotic/all-speed stability limit, is exactly
#     what the outer GA should be maximising here).
# ══════════════════════════════════════════════════════════════
_FREQS_OUTER = np.linspace(10, 800, 120)

def evaluate_individual(x, rng):
    x = repair_and_check(x)
    if x is None:
        return None
    D_cav, L_cav, D_abs, L_abs, Z_TIP, D_body_in = x

    modal = modal_reduce(D_cav, L_cav, Z_TIP, D_body_in)
    kd, cd = inner_GA_tune_kd_cd(modal, D_cav, L_cav, D_abs, L_abs, Z_TIP, rng)

    Ha, Hxa = frf(modal, _FREQS_OUTER, D_cav, L_cav, D_abs, L_abs, Z_TIP, kd, cd)
    Hb, Hxb = frf(modal, _FREQS_OUTER, D_cav, L_cav, D_abs, L_abs, Z_TIP, 0.0, 0.0)
    a = alim_from_FRF(Ha, Hxa)*1e3
    b = alim_from_FRF(Hb, Hxb)*1e3
    alim = max(min(a, b*50.0), b)

    K_tip = static_stiff(modal['Kf'])
    m_tot = total_mass(D_cav, L_cav, D_abs, L_abs, Z_TIP, D_body_in)
    md, _ = absorber_params(D_cav, L_cav, D_abs, L_abs, Z_TIP)
    fn1   = modal['wn'][0]/(2*np.pi)
    vf    = vol_fraction(D_cav, L_cav, D_abs, L_abs)

    clear_res = check_absorber_clearance(
        modal, D_cav, L_cav, D_abs, L_abs, Z_TIP, kd, cd)

    return dict(
        x=x.copy(),
        D_cav=D_cav, L_cav=L_cav, D_abs=D_abs, L_abs=L_abs,
        Z_TIP=Z_TIP, D_body_in=D_body_in,
        kd=kd, cd=cd, md=md*1e3,
        alim=alim, stiff=K_tip/1e6, mass=m_tot*1e3,
        vf=vf, fn1=fn1, modal=modal,
        delta_gap=clear_res['delta_gap']*1e6,
        delta_rel_max=clear_res['delta_rel_max']*1e6,
        clearance_ratio=clear_res['clearance_ratio'],
        collision=clear_res['collision']
    )

# %%
# ══════════════════════════════════════════════════════════════
# 15. OUTER NSGA-II  (unchanged — pure GA machinery)
# ══════════════════════════════════════════════════════════════

def non_dominated_sort(objs):
    """Fast non-dominated sort — Deb et al. 2002."""
    N   = len(objs)
    S   = [[] for _ in range(N)]
    n   = np.zeros(N, dtype=int)
    ranks = np.zeros(N, dtype=int)
    fronts = [[]]
    for i in range(N):
        for j in range(N):
            if i == j: continue
            if np.all(objs[i] <= objs[j]) and np.any(objs[i] < objs[j]):
                S[i].append(j)
            elif np.all(objs[j] <= objs[i]) and np.any(objs[j] < objs[i]):
                n[i] += 1
        if n[i] == 0:
            ranks[i] = 0
            fronts[0].append(i)
    k = 0
    while fronts[k]:
        next_front = []
        for i in fronts[k]:
            for j in S[i]:
                n[j] -= 1
                if n[j] == 0:
                    ranks[j] = k+1
                    next_front.append(j)
        k += 1
        fronts.append(next_front)
    fronts.pop()
    return ranks, fronts


def crowding_distance(objs_front):
    """Crowding distance for individuals in a single front."""
    n, M = objs_front.shape
    if n <= 2:
        return np.full(n, np.inf)
    dist = np.zeros(n)
    for m in range(M):
        order  = np.argsort(objs_front[:,m])
        f_min  = objs_front[order[0], m]
        f_max  = objs_front[order[-1],m]
        dist[order[0]]  = np.inf
        dist[order[-1]] = np.inf
        span = f_max - f_min if (f_max - f_min) > 1e-30 else 1e-30
        for k in range(1, n-1):
            dist[order[k]] += (objs_front[order[k+1],m] -
                               objs_front[order[k-1],m]) / span
    return dist


def nsga2_tournament(pop_results, ranks, crowd, rng):
    """NSGA-II binary tournament: lower rank wins; ties -> higher crowding."""
    N   = len(pop_results)
    i,j = rng.choice(N, size=2, replace=False)
    if   ranks[i] < ranks[j]:  return i
    elif ranks[i] > ranks[j]:  return j
    elif crowd[i] > crowd[j]:  return i
    elif crowd[i] < crowd[j]:  return j
    else:                      return rng.choice([i,j])


def run_outer_NSGA2(seed=42):
    """Run the outer NSGA-II optimisation loop."""
    rng = np.random.default_rng(seed)
    bounds = _BOUNDS_OUTER
    lo = bounds[:,0]; hi = bounds[:,1]
    N  = GA_OUTER_POP

    all_results  = []
    history      = dict(gen=[], best_alim=[], best_stiff=[], min_mass=[],
                        n_pareto=[], mean_alim=[])

    print(f"\n{'-'*64}")
    print(f"NSGA-II Outer GA  pop={N}  gen={GA_OUTER_NGEN}")
    print(f"{'-'*64}")

    n_vars = bounds.shape[0]

    pop_x = rng.uniform(lo, hi, size=(N, n_vars))
    pop_results = []
    print(f"Gen 0/{GA_OUTER_NGEN} — evaluating {N} individuals...")
    for k in range(N):
        inner_rng = np.random.default_rng(seed + k)
        res = evaluate_individual(pop_x[k], inner_rng)
        if res is None:
            for _retry in range(10):
                x_new = rng.uniform(lo, hi, size=n_vars)
                res = evaluate_individual(x_new, inner_rng)
                if res is not None:
                    break
        pop_results.append(res)
        if res is not None:
            print(f"  [{k+1:2d}/{N}] Dc={res['D_cav']*1e3:.0f}mm "
                  f"Lc={res['L_cav']*1e3:.0f}mm "
                  f"Da={res['D_abs']*1e3:.0f}mm "
                  f"La={res['L_abs']*1e3:.0f}mm "
                  f"Ztip={res['Z_TIP']*1e3:.0f}mm "
                  f"Dbi={res['D_body_in']*1e3:.0f}mm → "
                  f"alim={res['alim']:.2f}mm "
                  f"K={res['stiff']:.2f}MN/m "
                  f"m={res['mass']:.0f}g", flush=True)
        else:
            print(f"  [{k+1:2d}/{N}] infeasible", flush=True)

    all_results.extend([r for r in pop_results if r is not None])

    for gen in range(1, GA_OUTER_NGEN+1):
        valid_res  = [r for r in pop_results if r is not None]
        objs = np.array([[-r['alim'], -r['stiff'], r['mass']]
                          for r in valid_res])

        ranks, fronts = non_dominated_sort(objs)
        crowd = np.zeros(len(valid_res))
        for front in fronts:
            if len(front) < 1: continue
            cd = crowding_distance(objs[front])
            for i_local, i_global in enumerate(front):
                crowd[i_global] = cd[i_local]

        offspring_results = []
        n_children = 0
        while n_children < N:
            pi = nsga2_tournament(valid_res, ranks, crowd, rng)
            pj = nsga2_tournament(valid_res, ranks, crowd, rng)
            xp1 = valid_res[pi]['x']
            xp2 = valid_res[pj]['x']

            xc1, xc2 = sbx_crossover(xp1, xp2, bounds,
                                      GA_OUTER_ETA_C, GA_OUTER_PC, rng)
            xc1 = polynomial_mutation(xc1, bounds, GA_OUTER_ETA_M, GA_OUTER_PM, rng)
            xc2 = polynomial_mutation(xc2, bounds, GA_OUTER_ETA_M, GA_OUTER_PM, rng)

            if n_children == 0:
                print(f"Gen {gen}/{GA_OUTER_NGEN} — evaluating {N} offspring...")

            for xc in [xc1, xc2]:
                if n_children >= N: break
                inner_rng = np.random.default_rng(seed + gen*1000 + n_children)
                res = evaluate_individual(xc, inner_rng)
                offspring_results.append(res)

                if res is not None:
                    print(f"  [{n_children+1:2d}/{N}] Dc={res['D_cav']*1e3:.0f}mm "
                          f"Lc={res['L_cav']*1e3:.0f}mm "
                          f"Da={res['D_abs']*1e3:.0f}mm "
                          f"La={res['L_abs']*1e3:.0f}mm "
                          f"Ztip={res['Z_TIP']*1e3:.0f}mm "
                          f"Dbi={res['D_body_in']*1e3:.0f}mm → "
                          f"alim={res['alim']:.2f}mm "
                          f"K={res['stiff']:.2f}MN/m "
                          f"m={res['mass']:.0f}g", flush=True)
                else:
                    print(f"  [{n_children+1:2d}/{N}] infeasible", flush=True)

                n_children += 1

        combined = [r for r in pop_results + offspring_results if r is not None]
        if len(combined) == 0:
            continue
        objs_combined = np.array([[-r['alim'], -r['stiff'], r['mass']]
                                   for r in combined])

        ranks_c, fronts_c = non_dominated_sort(objs_combined)
        crowd_c = np.zeros(len(combined))
        for front in fronts_c:
            if len(front) < 1: continue
            cd = crowding_distance(objs_combined[front])
            for i_local, i_global in enumerate(front):
                crowd_c[i_global] = cd[i_local]

        sort_key = [(ranks_c[i], -crowd_c[i]) for i in range(len(combined))]
        order    = sorted(range(len(combined)), key=lambda i: sort_key[i])
        selected = order[:N]
        pop_results = [combined[i] for i in selected]

        all_results.extend([r for r in offspring_results if r is not None])

        pareto_idx  = [i for i,r in enumerate(combined)
                       if r is not None and ranks_c[i]==0]
        pareto_this = [combined[i] for i in pareto_idx]
        alims_  = [r['alim']  for r in pop_results if r is not None]
        stiffs_ = [r['stiff'] for r in pop_results if r is not None]
        masses_ = [r['mass']  for r in pop_results if r is not None]
        history['gen'].append(gen)
        history['best_alim'].append(max(alims_) if alims_ else 0)
        history['best_stiff'].append(max(stiffs_) if stiffs_ else 0)
        history['min_mass'].append(min(masses_) if masses_ else 0)
        history['n_pareto'].append(len(pareto_this))
        history['mean_alim'].append(np.mean(alims_) if alims_ else 0)

        print(f"Gen {gen:2d}/{GA_OUTER_NGEN} | "
              f"best alim={history['best_alim'][-1]:.2f}mm  "
              f"best K={history['best_stiff'][-1]:.2f}MN/m  "
              f"min m={history['min_mass'][-1]:.0f}g  "
              f"|Pareto|={history['n_pareto'][-1]}",
              flush=True)

    valid_final = [r for r in pop_results if r is not None]
    objs_final  = np.array([[-r['alim'], -r['stiff'], r['mass']]
                             for r in valid_final])
    ranks_f, fronts_f = non_dominated_sort(objs_final)
    pareto_front = [valid_final[i] for i in range(len(valid_final))
                    if ranks_f[i] == 0]

    return all_results, pareto_front, history

# %%
# ══════════════════════════════════════════════════════════════
# 16. POST-PROCESSING HELPERS  (unchanged)
# ══════════════════════════════════════════════════════════════

def extract_arrays(results):
    a  = np.array([r['alim']  for r in results])
    s  = np.array([r['stiff'] for r in results])
    m  = np.array([r['mass']  for r in results])
    fn = np.array([r['fn1']   for r in results])
    Dc = np.array([r['D_cav'] for r in results])*1e3
    Lc = np.array([r['L_cav'] for r in results])*1e3
    Da = np.array([r['D_abs'] for r in results])*1e3
    La = np.array([r['L_abs'] for r in results])*1e3
    vf = np.array([r['vf']    for r in results])
    kd = np.array([r['kd']    for r in results])
    cd = np.array([r['cd']    for r in results])
    md = np.array([r['md']    for r in results])
    Zt = np.array([r['Z_TIP'] for r in results])*1e3
    Dbi = np.array([r['D_body_in'] for r in results])*1e3
    dg = np.array([r['delta_gap'] for r in results])
    drm = np.array([r['delta_rel_max'] for r in results])
    cr = np.array([r['clearance_ratio'] for r in results])
    return dict(a=a,s=s,m=m,fn=fn,Dc=Dc,Lc=Lc,Da=Da,La=La,
                vf=vf,kd=kd,cd=cd,md=md, Zt=Zt, Dbi=Dbi, dg=dg, drm=drm, cr=cr)

def n01(x):
    return (x - x.min()) / (x.max() - x.min() + 1e-30)

def full_pareto(results):
    arr = extract_arrays(results)
    objs = np.column_stack([-arr['a'], -arr['s'], arr['m']])
    ranks, fronts = non_dominated_sort(objs)
    pareto_mask = (ranks == 0)
    score = (n01(arr['a']) + n01(arr['s']) + n01(-arr['m'])) / 3
    i_best  = np.argmax(score)
    i_alim  = np.argmax(arr['a'])
    i_stiff = np.argmax(arr['s'])
    i_mass  = np.argmin(arr['m'])
    i_worst = np.argmin(score)
    return pareto_mask, score, i_best, i_alim, i_stiff, i_mass, i_worst

# %%
# ══════════════════════════════════════════════════════════════
# 17. PLOTTING
#
#   Differences from the rotary-bar reference:
#     - No multi-speed FRF sweep panel, because the static bar's FRF
#       does not vary with spindle speed. Instead: a single "bare bar
#       vs tuned absorber" direct-FRF comparison panel.
#     - No cross-FRF (Hxy) panel — it is identically zero for a
#       stationary axisymmetric bar, so plotting it would show nothing.
#     - A new "absorber relative-displacement FRF" panel replaces it,
#       showing the same clearance-check quantity used in the
#       optimisation objective/constraint (Sec. 10.5), so the geometry
#       row's "gap" annotation ties back to an actual curve.
#     - The stability-lobe diagram is unchanged in physics (it was
#       already RPM-vs-regeneration-phase based) and is still plotted
#       against WORKPIECE RPM.
# ══════════════════════════════════════════════════════════════

def make_plots(all_results, pareto_front, history):
    arr = extract_arrays(all_results)
    a_v=arr['a']; s_v=arr['s']; m_v=arr['m']
    Dc_v=arr['Dc']; Lc_v=arr['Lc']; Da_v=arr['Da']; La_v=arr['La']
    vf_v=arr['vf']; kd_v=arr['kd']; cd_v=arr['cd']; md_v=arr['md']
    Zt_v=arr['Zt']; Dbi_v=arr['Dbi']; fn_v=arr['fn']
    dg_v=arr['dg']; drm_v=arr['drm']; cr_v=arr['cr']

    pareto_mask, score, i_best, i_alim, i_stiff, i_mass, i_worst = \
        full_pareto(all_results)

    BEST_C='#D62728'; PARETO_C='#FF7F0E'

    PARAM_SCORE_PANELS = [
        (Dc_v,                 'D_cav [mm]',            'Cavity diameter vs score',          None),
        (Lc_v,                 'L_cav [mm]',            'Cavity length vs score',            None),
        (Da_v,                 'D_abs [mm]',            'Absorber diameter vs score',        None),
        (La_v,                 'L_abs [mm]',            'Absorber length vs score',          None),
        (Zt_v,                 'Z_TIP [mm]',            'Tip offset vs score',               None),
        (Dbi_v,                'D_body_in [mm]',        'Body bore vs score',                None),
        (np.log10(kd_v),       'log10(kd) [N/m]',       'Absorber stiffness vs score',       None),
        (np.log10(cd_v),       'log10(cd) [Ns/m]',      'Absorber damping vs score',         None),
        (md_v,                 'Absorber mass [g]',     'Absorber mass vs score',            None),
        (vf_v*100,             'Fill fraction phi [%]', 'Fill fraction vs score',            None),
        (fn_v,                 'f_n1 [Hz]',             '1st natural freq vs score',         None),
        (np.clip(cr_v, 0, 5),  'Clearance ratio (capped 5)', 'Absorber clearance vs score',  1.0),
        (dg_v*1e3,             'Radial gap delta_gap [mm]',  'Cavity/absorber gap vs score', None),
        (drm_v*1e3,            'Max relative disp. [mm]',    'Absorber relative motion vs score', None),
        (a_v,                  'alim [mm]',             'Stability limit (objective)',       None),
        (s_v,                  'Stiffness K [MN/m]',    'Static stiffness (objective)',      None),
        (m_v,                  'Mass [g]',              'Total mass (objective)',            None),
    ]
    n_param_panels = len(PARAM_SCORE_PANELS)
    n_param_rows   = int(np.ceil(n_param_panels/4))

    n_rows_total = 1 + n_param_rows + 1 + 1   # conv + params + (FRF/SLD row) + geometry
    fig = plt.figure(figsize=(20, 3.6*n_rows_total))
    fig.suptitle(
        'STATIC Boring Bar (tool stationary, workpiece rotating)\n'
        'GA-Driven Multi-Objective Optimization\n'
        f'Outer NSGA-II: pop={GA_OUTER_POP}  gen={GA_OUTER_NGEN}  '
        f'SBX \u03b7c={GA_OUTER_ETA_C}  poly-mut \u03b7m={GA_OUTER_ETA_M}\n'
        f'Inner GA: pop={GA_INNER_POP}  gen={GA_INNER_NGEN}  '
        f'(replaces Den Hartog + scalar search)\n'
        f'5-section WC bar  \u00b7  TC absorber  \u00b7  V_abs\u2264{VOL_FRAC_MAX*100:.0f}%V_cav  \u00b7  '
        f'Single-point boring Nt=1  \u00b7  Objectives: alim\u2191  K\u2191  m\u2193\n'
        f'No bar rotordynamics (bar does not rotate)  \u00b7  regenerative chatter '
        f'driven by workpiece RPM (phase delay only)',
        fontsize=9.5, fontweight='bold', y=0.995)

    gs = gridspec.GridSpec(n_rows_total, 4, figure=fig, hspace=0.6, wspace=0.38)

    # ── Row 0: GA convergence history ──────────────────────────
    if history['gen']:
        ax=fig.add_subplot(gs[0,0])
        ax.plot(history['gen'], history['best_alim'], 'b-o', ms=4, lw=1.5, label='Best alim [mm]')
        ax.plot(history['gen'], history['mean_alim'], 'b--',ms=3, lw=1.0, label='Mean alim [mm]')
        ax.set_xlabel('Generation'); ax.set_ylabel('alim [mm]')
        ax.set_title('(a) Convergence — stability limit')
        ax.legend(fontsize=7); ax.grid(True, alpha=0.3)

        ax=fig.add_subplot(gs[0,1])
        ax.plot(history['gen'], history['best_stiff'], 'g-o', ms=4, lw=1.5)
        ax.set_xlabel('Generation'); ax.set_ylabel('Best K [MN/m]')
        ax.set_title('(b) Convergence — static stiffness')
        ax.grid(True, alpha=0.3)

        ax=fig.add_subplot(gs[0,2])
        ax.plot(history['gen'], history['min_mass'], 'm-o', ms=4, lw=1.5)
        ax.set_xlabel('Generation'); ax.set_ylabel('Min mass [g]')
        ax.set_title('(c) Convergence — minimum mass')
        ax.grid(True, alpha=0.3)

        ax=fig.add_subplot(gs[0,3])
        ax.plot(history['gen'], history['n_pareto'], 'k-o', ms=4, lw=1.5)
        ax.set_xlabel('Generation'); ax.set_ylabel('|Pareto front|')
        ax.set_title('(d) Pareto front growth per generation')
        ax.grid(True, alpha=0.3)

    # ── Rows 1..n_param_rows: every parameter vs score ─────────
    letters = 'efghijklmnopqrstuvwxyz'
    for idx, (xa, xl, ttl, vline) in enumerate(PARAM_SCORE_PANELS):
        row = 1 + idx//4; col = idx % 4
        ax = fig.add_subplot(gs[row, col])
        sc = ax.scatter(xa, score, c=score, cmap='RdYlGn', s=14, alpha=0.65,
                         vmin=0, vmax=1, edgecolors='none')
        ax.scatter(xa[pareto_mask], score[pareto_mask], s=55,
                   edgecolors=PARETO_C, facecolors='none', lw=1.4, zorder=4,
                   label=f'Pareto ({pareto_mask.sum()})')
        ax.scatter(xa[i_best], score[i_best], s=180, marker='*',
                   c=BEST_C, zorder=5, label='Best')
        if vline is not None:
            ax.axvline(vline, color='red', ls='--', lw=1.1, label='Collision (ratio=1)')
        plt.colorbar(sc, ax=ax, shrink=0.8).set_label('Score', fontsize=7)
        letter = letters[idx] if idx < len(letters) else f'#{idx+1}'
        ax.set_xlabel(xl); ax.set_ylabel('Combined score')
        ax.set_title(f'({letter}) {ttl}')
        ax.legend(fontsize=6.5); ax.grid(True, alpha=0.3)

    # ── Best-design data needed for FRF / SLD panels ───────────
    best_r = all_results[i_best]
    Dc_b=best_r['D_cav']; Lc_b=best_r['L_cav']
    Da_b=best_r['D_abs']; La_b=best_r['L_abs']
    kd_b=best_r['kd'];    cd_b=best_r['cd']
    Zt_b=best_r['Z_TIP']; Db_b=best_r['D_body_in']
    modal_b=best_r['modal']
    freqs_frf_plot = np.linspace(5, 800, 800)

    frf_row = 1 + n_param_rows

    Hxx_abs, _ = frf(modal_b, freqs_frf_plot, Dc_b, Lc_b, Da_b, La_b, Zt_b, kd_b, cd_b)
    Hxx_bare, _ = frf(modal_b, freqs_frf_plot, Dc_b, Lc_b, Da_b, La_b, Zt_b, 0.0, 0.0)

    def _annotate_peak(ax, freqs, mag, color):
        if not len(mag) or not np.any(np.isfinite(mag)):
            return
        kpk = int(np.argmax(mag))
        ax.annotate(f'{freqs[kpk]:.0f} Hz', xy=(freqs[kpk], mag[kpk]),
                    xytext=(0, 6), textcoords='offset points',
                    fontsize=6.5, color=color, ha='center')

    # ── Panel 1: direct FRF, bare bar vs tuned absorber ─────────
    ax = fig.add_subplot(gs[frf_row, 0])
    mag_bare = np.clip(np.abs(Hxx_bare), 1e-14, None)
    mag_abs  = np.clip(np.abs(Hxx_abs),  1e-14, None)
    ax.semilogy(freqs_frf_plot, mag_bare, 'gray', lw=1.2, ls=':', label='Bare bar (no absorber)')
    ax.semilogy(freqs_frf_plot, mag_abs,  color='#1F77B4', lw=1.4, label='With tuned TC absorber')
    _annotate_peak(ax, freqs_frf_plot, mag_bare, 'gray')
    _annotate_peak(ax, freqs_frf_plot, mag_abs, '#1F77B4')
    ax.set_xlabel('Freq [Hz]'); ax.set_ylabel('|H_xx| tip [m/N]')
    ax.set_title(f'(direct FRF) Static bar — best design\nDc={Dc_v[i_best]:.0f} Lc={Lc_v[i_best]:.0f} '
                 f'Da={Da_v[i_best]:.0f} La={La_v[i_best]:.0f} mm')
    ax.legend(fontsize=7); ax.grid(True, which='both', alpha=0.3); ax.set_xlim(5, 800)

    # ── Panel 2: stability lobe diagram (workpiece RPM) ─────────
    ax = fig.add_subplot(gs[frf_row, 1])
    _, sld_res = plot_stability_lobe_diagram(
        modal_b, Dc_b, Lc_b, Da_b, La_b, Zt_b, kd_b, cd_b,
        rpm_max=6000, ax=ax, title='(SLD) Stability lobe diagram — by mode\n(vs. workpiece RPM)')

    # ── Panel 3: direct FRF with the absolute stability limit ──
    ax = fig.add_subplot(gs[frf_row, 2])
    ax.semilogy(freqs_frf_plot, mag_abs, color='#1F77B4', lw=1.4, label='With tuned absorber')
    ax.set_xlabel('Freq [Hz]'); ax.set_ylabel('|H_xx| tip [m/N]')
    a_lim_crit = sld_res['a_lim_crit']
    ttl_extra = f'a_lim_crit={a_lim_crit:.2f} mm' if np.isfinite(a_lim_crit) else 'a_lim_crit: n/a'
    ax.set_title(f'(direct FRF vs SLD) Absolute stability limit\n{ttl_extra}')
    ax.legend(fontsize=7); ax.grid(True, which='both', alpha=0.3); ax.set_xlim(5, 800)

    # ── Panel 4: absorber relative-displacement FRF (clearance) ─
    ax = fig.add_subplot(gs[frf_row, 3])
    Hrel_b = relative_displacement_FRF(modal_b, freqs_frf_plot, Dc_b, Lc_b, Da_b, La_b, Zt_b, kd_b, cd_b)
    delta_gap_mm = (Dc_b - Da_b)/2*1e3
    delta_rel_mm = F_REP_DEFAULT*np.abs(Hrel_b)*1e3
    ax.plot(freqs_frf_plot, delta_rel_mm, color='#E07B20', lw=1.3, label='Relative disp. (rep. force)')
    ax.axhline(delta_gap_mm, color='red', ls='--', lw=1.2, label=f'Radial gap = {delta_gap_mm:.2f} mm')
    ax.set_xlabel('Freq [Hz]'); ax.set_ylabel('Beam-absorber rel. disp. [mm]')
    ax.set_title('(clearance) Absorber vs cavity wall\nrepresentative force = '
                 f'{F_REP_DEFAULT:.0f} N')
    ax.legend(fontsize=7); ax.grid(True, alpha=0.3); ax.set_xlim(5, 800)

    # ── Final row: optimal-design cross-section drawing ─────────
    geom_row = frf_row + 1
    ax = fig.add_subplot(gs[geom_row, :])
    z_cav_b = L_total - Zt_b - Lc_b; z2_ = L1 + L2; z4_ = z_cav_b + Lc_b
    zz = np.linspace(0, L_total, 4000)
    Ro_p, Ri_p = [], []
    for zp in zz:
        if zp < L1: Ro = D1_out/2
        elif zp < z2_: Ro = D1_out/2 + (zp-L1)/L2*(D_main-D1_out)/2
        else: Ro = D_main/2
        if zp < z_cav_b: Ri = Db_b/2
        elif zp < z4_: Ri = Dc_b/2
        else: Ri = 0.0
        Ri = np.clip(Ri, 0, Ro-1e-4)
        Ro_p.append(Ro*1e3); Ri_p.append(Ri*1e3)
    Ro_p = np.array(Ro_p); Ri_p = np.array(Ri_p)
    ax.fill_between(zz*1e3, Ri_p,  Ro_p,  alpha=0.70, color='#4472C4', label='WC body')
    ax.fill_between(zz*1e3, -Ro_p, -Ri_p, alpha=0.70, color='#4472C4')
    ax.fill_between(zz*1e3, Ri_p, -Ri_p,  alpha=0.10, color='lightcyan', label='Body bore / cavity')
    abs_start = z_cav_b + (Lc_b-La_b)/2; abs_end = abs_start + La_b
    R_abs_plot = Da_b/2*1e3
    ax.fill_betweenx([-R_abs_plot, R_abs_plot], abs_start*1e3, abs_end*1e3,
                      alpha=0.88, color='#E07B20',
                      label=f'TC absorber  D={Da_v[i_best]:.0f}mm  L={La_v[i_best]:.0f}mm  '
                            f'm={md_v[i_best]:.0f}g  \u03c6={vf_v[i_best]*100:.0f}%')
    ax.axvline(z_cav_b*1e3, color=BEST_C, ls='--', lw=1.2)
    ax.axvline(z4_*1e3,     color=BEST_C, ls='--', lw=1.2)
    for xv in [L1*1e3, z2_*1e3]:
        ax.axvline(xv, color='gray', ls=':', lw=0.8)
    ax.set_xlim(-2, L_total*1e3+2); ax.set_ylim(-36, 50)
    ax.set_xlabel('Axial position z from fixed end [mm]', fontsize=10)
    ax.set_ylabel('Radius [mm]', fontsize=10)
    ax.set_title(
        f'(geometry) Optimal design — static bar, workpiece rotating\n'
        f'Cavity: D_cav={Dc_v[i_best]:.0f}mm  L_cav={Lc_v[i_best]:.0f}mm  z_tip={Zt_b*1e3:.0f}mm  |  '
        f'Absorber: D_abs={Da_v[i_best]:.0f}mm  L_abs={La_v[i_best]:.0f}mm  \u03c6={vf_v[i_best]*100:.0f}%  '
        f'md={md_v[i_best]:.0f}g\n'
        f'kd={kd_v[i_best]:.3e} N/m  \u00b7  cd={cd_v[i_best]:.0f} Ns/m  \u00b7  '
        f'alim={a_v[i_best]:.2f} mm  \u00b7  K={s_v[i_best]:.2f} MN/m  \u00b7  mass={m_v[i_best]:.0f} g',
        fontsize=9.5)
    ax.legend(fontsize=8, loc='upper right'); ax.grid(True, alpha=0.25)
    ax.set_aspect('equal', adjustable='box')

    plt.tight_layout()
    plt.show()

# %%
# ══════════════════════════════════════════════════════════════
# 18. ENTRY POINT
# ══════════════════════════════════════════════════════════════
if __name__ == '__main__':
    all_results, pareto_front, history = run_outer_NSGA2(seed=42)

    arr = extract_arrays(all_results)
    _, score, i_best, i_alim, i_stiff, i_mass, _ = full_pareto(all_results)
    print("\n"+"="*70)
    print("FINAL RESULTS — GA Multi-Objective Optimization (static bar)")
    print("="*70)
    hdr = ("  {:<18} {:>7} {:>7} {:>7} {:>7} {:>8} {:>7} {:>6}"
           .format('Criterion','Dc[mm]','Lc[mm]','Da[mm]','La[mm]',
                   'alim[mm]','K[MN/m]','m[g]'))
    print(hdr); print("  "+"-"*68)
    for tag,idx in [("Max alim",i_alim),("Max stiffness",i_stiff),
                    ("Min mass",i_mass),("★ Best balanced",i_best)]:
        r=all_results[idx]
        print("  {:<18} {:>7.1f} {:>7.1f} {:>7.1f} {:>7.1f} "
              "{:>8.3f} {:>7.3f} {:>6.0f}".format(
              tag,
              r['D_cav']*1e3, r['L_cav']*1e3,
              r['D_abs']*1e3, r['L_abs']*1e3,
              r['alim'], r['stiff'], r['mass']))
    print(f"\n  Pareto front (final): {len(pareto_front)} individuals")
    print(f"  Total evaluations:   {len(all_results)}")
    best=all_results[i_best]
    print(f"\n  Best absorber tuning: kd={best['kd']:.3e} N/m  "
          f"cd={best['cd']:.0f} Ns/m  md={best['md']:.0f} g")
    print("="*70)
# Out:
# ----------------------------------------------------------------
# NSGA-II Outer GA  pop=40  gen=20
# ----------------------------------------------------------------
# Gen 0/20 — evaluating 40 individuals...
#   [ 1/40] Dc=29mm Lc=86mm Da=29mm La=60mm Ztip=41mm Dbi=29mm → alim=5.00mm K=5.80MN/m m=3605g
#   [ 2/40] Dc=28mm Lc=131mm Da=9mm La=79mm Ztip=74mm Dbi=28mm → alim=2.81mm K=5.90MN/m m=3306g
#   [ 3/40] Dc=25mm Lc=108mm Da=17mm La=42mm Ztip=97mm Dbi=12mm → alim=1.49mm K=6.64MN/m m=4111g
#   [ 4/40] Dc=30mm Lc=59mm Da=26mm La=53mm Ztip=146mm Dbi=30mm → alim=0.96mm K=5.90MN/m m=4002g
#   [ 5/40] Dc=29mm Lc=49mm Da=18mm La=12mm Ztip=49mm Dbi=26mm → alim=4.60mm K=6.20MN/m m=3274g
#   [ 6/40] Dc=28mm Lc=119mm Da=14mm La=66mm Ztip=86mm Dbi=15mm → alim=1.44mm K=6.26MN/m m=3897g
#   [ 7/40] Dc=13mm Lc=91mm Da=11mm La=85mm Ztip=82mm Dbi=13mm → alim=2.45mm K=7.29MN/m m=4425g
#   [ 8/40] Dc=27mm Lc=67mm Da=27mm La=47mm Ztip=76mm Dbi=17mm → alim=3.58mm K=6.91MN/m m=4292g
#   [ 9/40] Dc=26mm Lc=41mm Da=11mm La=6mm Ztip=124mm Dbi=26mm → alim=1.15mm K=6.44MN/m m=3694g
#   [10/40] Dc=27mm Lc=137mm Da=18mm La=98mm Ztip=47mm Dbi=13mm → alim=3.05mm K=6.60MN/m m=4076g
#   [11/40] Dc=26mm Lc=91mm Da=21mm La=91mm Ztip=106mm Dbi=23mm → alim=1.71mm K=6.51MN/m m=4181g
#   [12/40] Dc=23mm Lc=66mm Da=6mm La=66mm Ztip=56mm Dbi=20mm → alim=4.24mm K=6.96MN/m m=3810g
#   [13/40] Dc=30mm Lc=55mm Da=7mm La=51mm Ztip=65mm Dbi=26mm → alim=3.18mm K=6.18MN/m m=3326g
#   [14/40] Dc=23mm Lc=77mm Da=23mm La=54mm Ztip=128mm Dbi=14mm → alim=1.46mm K=6.92MN/m m=4479g
#   [15/40] Dc=11mm Lc=34mm Da=11mm La=23mm Ztip=49mm Dbi=11mm → alim=5.00mm K=7.32MN/m m=4393g
#   [16/40] Dc=14mm Lc=124mm Da=14mm La=67mm Ztip=66mm Dbi=14mm → alim=2.29mm K=7.28MN/m m=4399g
#   [17/40] Dc=19mm Lc=33mm Da=8mm La=33mm Ztip=139mm Dbi=19mm → alim=1.96mm K=7.14MN/m m=4180g
#   [18/40] Dc=16mm Lc=121mm Da=16mm La=85mm Ztip=84mm Dbi=16mm → alim=1.71mm K=7.20MN/m m=4417g
#   [19/40] Dc=12mm Lc=138mm Da=12mm La=38mm Ztip=67mm Dbi=12mm → alim=3.86mm K=7.30MN/m m=4377g
#   [20/40] Dc=14mm Lc=123mm Da=14mm La=86mm Ztip=82mm Dbi=14mm → alim=1.48mm K=7.26MN/m m=4454g
#   [21/40] Dc=24mm Lc=117mm Da=7mm La=73mm Ztip=35mm Dbi=22mm → alim=4.69mm K=6.76MN/m m=3593g
#   [22/40] Dc=18mm Lc=42mm Da=8mm La=42mm Ztip=50mm Dbi=18mm → alim=4.69mm K=7.12MN/m m=4006g
#   [23/40] Dc=24mm Lc=60mm Da=22mm La=9mm Ztip=145mm Dbi=22mm → alim=1.15mm K=6.85MN/m m=4035g
#   [24/40] Dc=29mm Lc=32mm Da=19mm La=32mm Ztip=143mm Dbi=24mm → alim=1.57mm K=6.58MN/m m=3986g
#   [25/40] Dc=21mm Lc=60mm Da=14mm La=60mm Ztip=83mm Dbi=11mm → alim=2.85mm K=7.23MN/m m=4386g
#   [26/40] Dc=30mm Lc=154mm Da=9mm La=96mm Ztip=43mm Dbi=26mm → alim=4.47mm K=5.71MN/m m=3126g
#   [27/40] Dc=17mm Lc=119mm Da=17mm La=83mm Ztip=43mm Dbi=17mm → alim=3.83mm K=7.17MN/m m=4320g
#   [28/40] Dc=16mm Lc=26mm Da=16mm La=18mm Ztip=130mm Dbi=16mm → alim=2.41mm K=7.25MN/m m=4316g
#   [29/40] Dc=18mm Lc=144mm Da=13mm La=89mm Ztip=61mm Dbi=18mm → alim=1.98mm K=7.14MN/m m=4208g
#   [30/40] Dc=14mm Lc=27mm Da=14mm La=19mm Ztip=137mm Dbi=14mm → alim=2.56mm K=7.29MN/m m=4377g
#   [31/40] Dc=31mm Lc=82mm Da=20mm La=57mm Ztip=123mm Dbi=26mm → alim=1.06mm K=5.56MN/m m=3762g
#   [32/40] Dc=19mm Lc=34mm Da=19mm La=24mm Ztip=142mm Dbi=16mm → alim=2.27mm K=7.21MN/m m=4354g
#   [33/40] Dc=13mm Lc=103mm Da=9mm La=34mm Ztip=102mm Dbi=13mm → alim=2.42mm K=7.29MN/m m=4358g
#   [34/40] Dc=15mm Lc=67mm Da=15mm La=47mm Ztip=90mm Dbi=13mm → alim=2.89mm K=7.27MN/m m=4392g
#   [35/40] Dc=10mm Lc=54mm Da=9mm La=54mm Ztip=45mm Dbi=10mm → alim=5.00mm K=7.33MN/m m=4415g
#   [36/40] Dc=27mm Lc=89mm Da=11mm La=89mm Ztip=116mm Dbi=27mm → alim=1.93mm K=6.32MN/m m=3721g
#   [37/40] Dc=13mm Lc=39mm Da=13mm La=27mm Ztip=66mm Dbi=13mm → alim=5.00mm K=7.29MN/m m=4325g
#   [38/40] Dc=26mm Lc=163mm Da=13mm La=157mm Ztip=33mm Dbi=23mm → alim=2.96mm K=6.42MN/m m=3664g
#   [39/40] Dc=25mm Lc=36mm Da=9mm La=36mm Ztip=146mm Dbi=24mm → alim=1.59mm K=6.72MN/m m=3917g
#   [40/40] Dc=32mm Lc=141mm Da=18mm La=134mm Ztip=32mm Dbi=13mm → alim=4.79mm K=5.76MN/m m=3861g
# Gen 1/20 — evaluating 40 offspring...
#   [ 1/40] Dc=12mm Lc=62mm Da=6mm La=38mm Ztip=56mm Dbi=12mm → alim=2.54mm K=7.30MN/m m=4313g
#   [ 2/40] Dc=24mm Lc=128mm Da=12mm La=73mm Ztip=67mm Dbi=22mm → alim=2.21mm K=6.73MN/m m=3811g
#   [ 3/40] Dc=14mm Lc=67mm Da=6mm La=67mm Ztip=56mm Dbi=12mm → alim=4.19mm K=7.30MN/m m=4310g
#   [ 4/40] Dc=22mm Lc=90mm Da=11mm La=84mm Ztip=81mm Dbi=20mm → alim=2.67mm K=6.92MN/m m=3981g
#   [ 5/40] Dc=11mm Lc=54mm Da=9mm La=54mm Ztip=45mm Dbi=10mm → alim=5.00mm K=7.33MN/m m=4413g
#   [ 6/40] Dc=29mm Lc=50mm Da=18mm La=12mm Ztip=49mm Dbi=26mm → alim=5.00mm K=6.20MN/m m=3273g
#   [ 7/40] Dc=25mm Lc=110mm Da=9mm La=43mm Ztip=44mm Dbi=12mm → alim=4.13mm K=6.99MN/m m=3936g
#   [ 8/40] Dc=30mm Lc=109mm Da=17mm La=95mm Ztip=96mm Dbi=26mm → alim=1.34mm K=5.76MN/m m=3726g
#   [ 9/40] Dc=17mm Lc=86mm Da=6mm La=67mm Ztip=56mm Dbi=17mm → alim=3.96mm K=7.15MN/m m=4049g
#   [10/40] Dc=24mm Lc=141mm Da=13mm La=90mm Ztip=61mm Dbi=20mm → alim=1.97mm K=6.74MN/m m=3894g
#   [11/40] Dc=16mm Lc=26mm Da=15mm La=15mm Ztip=45mm Dbi=16mm → alim=5.00mm K=7.22MN/m m=4155g
#   [12/40] Dc=29mm Lc=86mm Da=29mm La=61mm Ztip=119mm Dbi=28mm → alim=1.22mm K=5.95MN/m m=4100g
#   [13/40] Dc=10mm Lc=40mm Da=8mm La=25mm Ztip=49mm Dbi=10mm → alim=4.12mm K=7.33MN/m m=4394g
#   [14/40] Dc=18mm Lc=42mm Da=11mm La=42mm Ztip=51mm Dbi=18mm → alim=5.00mm K=7.11MN/m m=4022g
#   [15/40] Dc=20mm Lc=41mm Da=14mm La=5mm Ztip=48mm Dbi=18mm → alim=2.32mm K=7.13MN/m m=3986g
#   [16/40] Dc=24mm Lc=144mm Da=18mm La=97mm Ztip=61mm Dbi=24mm → alim=2.09mm K=6.59MN/m m=3913g
#   [17/40] Dc=16mm Lc=73mm Da=15mm La=47mm Ztip=32mm Dbi=13mm → alim=5.00mm K=7.29MN/m m=4325g
#   [18/40] Dc=31mm Lc=114mm Da=20mm La=114mm Ztip=91mm Dbi=12mm → alim=1.44mm K=5.59MN/m m=4192g
#   [19/40] Dc=11mm Lc=34mm Da=8mm La=24mm Ztip=49mm Dbi=10mm → alim=4.34mm K=7.33MN/m m=4392g
#   [20/40] Dc=18mm Lc=41mm Da=11mm La=41mm Ztip=50mm Dbi=18mm → alim=5.00mm K=7.12MN/m m=4032g
#   [21/40] Dc=19mm Lc=34mm Da=8mm La=34mm Ztip=33mm Dbi=19mm → alim=5.00mm K=7.08MN/m m=3904g
#   [22/40] Dc=25mm Lc=66mm Da=13mm La=66mm Ztip=139mm Dbi=23mm → alim=1.23mm K=6.66MN/m m=4006g
#   [23/40] Dc=13mm Lc=26mm Da=13mm La=18mm Ztip=70mm Dbi=13mm → alim=5.00mm K=7.30MN/m m=4335g
#   [24/40] Dc=14mm Lc=39mm Da=14mm La=24mm Ztip=133mm Dbi=14mm → alim=2.07mm K=7.28MN/m m=4385g
#   [25/40] Dc=15mm Lc=32mm Da=15mm La=18mm Ztip=123mm Dbi=15mm → alim=3.35mm K=7.25MN/m m=4310g
#   [26/40] Dc=32mm Lc=81mm Da=19mm La=57mm Ztip=124mm Dbi=26mm → alim=1.00mm K=5.53MN/m m=3775g
#   [27/40] Dc=15mm Lc=26mm Da=15mm La=18mm Ztip=44mm Dbi=13mm → alim=5.00mm K=7.29MN/m m=4297g
#   [28/40] Dc=27mm Lc=72mm Da=18mm La=72mm Ztip=133mm Dbi=16mm → alim=1.31mm K=6.58MN/m m=4285g
#   [29/40] Dc=10mm Lc=55mm Da=7mm La=53mm Ztip=45mm Dbi=10mm → alim=4.94mm K=7.33MN/m m=4391g
#   [30/40] Dc=23mm Lc=65mm Da=9mm La=65mm Ztip=56mm Dbi=19mm → alim=5.00mm K=6.99MN/m m=3878g
#   [31/40] Dc=32mm Lc=141mm Da=19mm La=134mm Ztip=32mm Dbi=13mm → alim=5.00mm K=5.76MN/m m=3911g
#   [32/40] Dc=30mm Lc=154mm Da=9mm La=96mm Ztip=43mm Dbi=26mm → alim=5.00mm K=5.71MN/m m=3126g
#   [33/40] Dc=23mm Lc=66mm Da=5mm La=60mm Ztip=39mm Dbi=19mm → alim=4.09mm K=7.05MN/m m=3836g
#   [34/40] Dc=29mm Lc=86mm Da=29mm La=60mm Ztip=56mm Dbi=28mm → alim=4.97mm K=5.85MN/m m=3729g
#   [35/40] Dc=15mm Lc=124mm Da=14mm La=70mm Ztip=47mm Dbi=13mm → alim=3.09mm K=7.26MN/m m=4356g
#   [36/40] Dc=25mm Lc=137mm Da=18mm La=96mm Ztip=66mm Dbi=13mm → alim=1.92mm K=6.63MN/m m=4171g
#   [37/40] Dc=19mm Lc=34mm Da=8mm La=26mm Ztip=77mm Dbi=10mm → alim=3.64mm K=7.30MN/m m=4347g
#   [38/40] Dc=21mm Lc=59mm Da=14mm La=59mm Ztip=140mm Dbi=19mm → alim=1.26mm K=7.05MN/m m=4255g
#   [39/40] Dc=26mm Lc=89mm Da=12mm La=89mm Ztip=32mm Dbi=13mm → alim=5.00mm K=7.10MN/m m=4053g
#   [40/40] Dc=33mm Lc=89mm Da=18mm La=89mm Ztip=116mm Dbi=26mm → alim=1.06mm K=5.12MN/m m=3734g
# Gen  1/20 | best alim=5.00mm  best K=7.33MN/m  min m=3126g  |Pareto|=24
# Gen 2/20 — evaluating 40 offspring...
#   [ 1/40] Dc=16mm Lc=21mm Da=5mm La=15mm Ztip=45mm Dbi=16mm → alim=2.77mm K=7.21MN/m m=4096g
#   [ 2/40] Dc=21mm Lc=66mm Da=17mm La=66mm Ztip=56mm Dbi=19mm → alim=4.12mm K=7.01MN/m m=4067g
#   [ 3/40] Dc=12mm Lc=34mm Da=8mm La=23mm Ztip=49mm Dbi=10mm → alim=4.43mm K=7.32MN/m m=4377g
#   [ 4/40] Dc=17mm Lc=34mm Da=11mm La=25mm Ztip=77mm Dbi=10mm → alim=3.40mm K=7.31MN/m m=4383g
#   [ 5/40] Dc=12mm Lc=47mm Da=9mm La=31mm Ztip=43mm Dbi=11mm → alim=5.00mm K=7.32MN/m m=4372g
#   [ 6/40] Dc=28mm Lc=149mm Da=11mm La=94mm Ztip=49mm Dbi=26mm → alim=2.29mm K=6.00MN/m m=3307g
#   [ 7/40] Dc=11mm Lc=26mm Da=11mm La=19mm Ztip=50mm Dbi=11mm → alim=2.96mm K=7.32MN/m m=4380g
#   [ 8/40] Dc=11mm Lc=33mm Da=11mm La=23mm Ztip=70mm Dbi=10mm → alim=4.98mm K=7.33MN/m m=4419g
#   [ 9/40] Dc=18mm Lc=41mm Da=11mm La=41mm Ztip=52mm Dbi=18mm → alim=5.00mm K=7.12MN/m m=4035g
#   [10/40] Dc=18mm Lc=41mm Da=11mm La=41mm Ztip=50mm Dbi=18mm → alim=5.00mm K=7.12MN/m m=4035g
#   [11/40] Dc=19mm Lc=34mm Da=8mm La=25mm Ztip=43mm Dbi=11mm → alim=4.78mm K=7.31MN/m m=4309g
#   [12/40] Dc=33mm Lc=128mm Da=9mm La=104mm Ztip=77mm Dbi=26mm → alim=2.68mm K=4.96MN/m m=3185g
#   [13/40] Dc=18mm Lc=40mm Da=8mm La=32mm Ztip=33mm Dbi=18mm → alim=5.00mm K=7.12MN/m m=3957g
#   [14/40] Dc=26mm Lc=154mm Da=13mm La=154mm Ztip=51mm Dbi=23mm → alim=2.14mm K=6.40MN/m m=3751g
#   [15/40] Dc=18mm Lc=41mm Da=11mm La=41mm Ztip=44mm Dbi=18mm → alim=5.00mm K=7.12MN/m m=4017g
#   [16/40] Dc=12mm Lc=138mm Da=12mm La=44mm Ztip=67mm Dbi=12mm → alim=3.80mm K=7.30MN/m m=4387g
#   [17/40] Dc=13mm Lc=36mm Da=6mm La=22mm Ztip=55mm Dbi=10mm → alim=2.40mm K=7.32MN/m m=4361g
#   [18/40] Dc=19mm Lc=65mm Da=7mm La=65mm Ztip=77mm Dbi=13mm → alim=3.43mm K=7.25MN/m m=4241g
#   [19/40] Dc=13mm Lc=38mm Da=11mm La=38mm Ztip=51mm Dbi=13mm → alim=4.93mm K=7.30MN/m m=4330g
#   [20/40] Dc=17mm Lc=139mm Da=12mm La=42mm Ztip=66mm Dbi=17mm → alim=4.12mm K=7.15MN/m m=4125g
#   [21/40] Dc=24mm Lc=51mm Da=8mm La=14mm Ztip=34mm Dbi=22mm → alim=3.47mm K=6.84MN/m m=3616g
#   [22/40] Dc=27mm Lc=116mm Da=18mm La=71mm Ztip=50mm Dbi=27mm → alim=2.91mm K=6.15MN/m m=3509g
#   [23/40] Dc=24mm Lc=117mm Da=7mm La=73mm Ztip=35mm Dbi=22mm → alim=4.91mm K=6.76MN/m m=3593g
#   [24/40] Dc=10mm Lc=54mm Da=9mm La=54mm Ztip=53mm Dbi=10mm → alim=5.00mm K=7.33MN/m m=4422g
#   [25/40] Dc=22mm Lc=39mm Da=8mm La=29mm Ztip=43mm Dbi=18mm → alim=4.92mm K=7.11MN/m m=3936g
#   [26/40] Dc=30mm Lc=155mm Da=9mm La=99mm Ztip=50mm Dbi=26mm → alim=3.88mm K=5.58MN/m m=3144g
#   [27/40] Dc=10mm Lc=40mm Da=9mm La=6mm Ztip=44mm Dbi=10mm → alim=2.65mm K=7.33MN/m m=4374g
#   [28/40] Dc=20mm Lc=55mm Da=14mm La=53mm Ztip=49mm Dbi=18mm → alim=5.00mm K=7.13MN/m m=4087g
#   [29/40] Dc=17mm Lc=35mm Da=8mm La=25mm Ztip=50mm Dbi=10mm → alim=4.53mm K=7.32MN/m m=4337g
#   [30/40] Dc=18mm Lc=38mm Da=8mm La=38mm Ztip=77mm Dbi=18mm → alim=4.07mm K=7.12MN/m m=4065g
#   [31/40] Dc=18mm Lc=44mm Da=7mm La=43mm Ztip=33mm Dbi=18mm → alim=4.09mm K=7.12MN/m m=3966g
#   [32/40] Dc=26mm Lc=154mm Da=14mm La=154mm Ztip=51mm Dbi=23mm → alim=2.28mm K=6.40MN/m m=3777g
#   [33/40] Dc=10mm Lc=55mm Da=7mm La=53mm Ztip=45mm Dbi=10mm → alim=3.68mm K=7.33MN/m m=4391g
#   [34/40] Dc=17mm Lc=119mm Da=17mm La=83mm Ztip=43mm Dbi=17mm → alim=3.83mm K=7.17MN/m m=4320g
#   [35/40] Dc=18mm Lc=84mm Da=6mm La=67mm Ztip=43mm Dbi=18mm → alim=4.22mm K=7.14MN/m m=4009g
#   [36/40] Dc=30mm Lc=149mm Da=9mm La=95mm Ztip=56mm Dbi=26mm → alim=2.77mm K=5.69MN/m m=3225g
#   [37/40] Dc=10mm Lc=44mm Da=7mm La=24mm Ztip=33mm Dbi=10mm → alim=3.92mm K=7.33MN/m m=4384g
#   [38/40] Dc=24mm Lc=117mm Da=8mm La=74mm Ztip=51mm Dbi=22mm → alim=4.05mm K=6.70MN/m m=3636g
#   [39/40] Dc=21mm Lc=67mm Da=6mm La=67mm Ztip=36mm Dbi=20mm → alim=4.92mm K=7.00MN/m m=3805g
#   [40/40] Dc=25mm Lc=116mm Da=7mm La=73mm Ztip=54mm Dbi=22mm → alim=3.75mm K=6.64MN/m m=3600g
# Gen  2/20 | best alim=5.00mm  best K=7.33MN/m  min m=3126g  |Pareto|=39
# Gen 3/20 — evaluating 40 offspring...
#   [ 1/40] Dc=12mm Lc=34mm Da=6mm La=22mm Ztip=33mm Dbi=11mm → alim=3.82mm K=7.32MN/m m=4329g
#   [ 2/40] Dc=19mm Lc=36mm Da=8mm La=34mm Ztip=56mm Dbi=18mm → alim=4.32mm K=7.10MN/m m=3982g
#   [ 3/40] Dc=17mm Lc=66mm Da=5mm La=60mm Ztip=41mm Dbi=17mm → alim=3.66mm K=7.15MN/m m=4009g
#   [ 4/40] Dc=23mm Lc=86mm Da=6mm La=67mm Ztip=54mm Dbi=19mm → alim=3.97mm K=7.00MN/m m=3860g
#   [ 5/40] Dc=22mm Lc=58mm Da=9mm La=58mm Ztip=43mm Dbi=19mm → alim=5.00mm K=7.01MN/m m=3849g
#   [ 6/40] Dc=29mm Lc=149mm Da=9mm La=107mm Ztip=56mm Dbi=26mm → alim=3.45mm K=5.77MN/m m=3248g
#   [ 7/40] Dc=11mm Lc=34mm Da=10mm La=24mm Ztip=50mm Dbi=11mm → alim=5.00mm K=7.32MN/m m=4387g
#   [ 8/40] Dc=17mm Lc=139mm Da=12mm La=41mm Ztip=66mm Dbi=17mm → alim=3.79mm K=7.17MN/m m=4149g
#   [ 9/40] Dc=21mm Lc=67mm Da=6mm La=63mm Ztip=36mm Dbi=21mm → alim=4.40mm K=6.91MN/m m=3735g
#   [10/40] Dc=13mm Lc=36mm Da=6mm La=22mm Ztip=55mm Dbi=10mm → alim=3.06mm K=7.32MN/m m=4361g
#   [11/40] Dc=17mm Lc=28mm Da=6mm La=25mm Ztip=50mm Dbi=10mm → alim=2.21mm K=7.32MN/m m=4334g
#   [12/40] Dc=17mm Lc=85mm Da=8mm La=67mm Ztip=56mm Dbi=17mm → alim=5.00mm K=7.15MN/m m=4076g
#   [13/40] Dc=13mm Lc=24mm Da=6mm La=22mm Ztip=59mm Dbi=10mm → alim=3.04mm K=7.32MN/m m=4370g
#   [14/40] Dc=12mm Lc=34mm Da=9mm La=23mm Ztip=49mm Dbi=10mm → alim=4.47mm K=7.32MN/m m=4382g
#   [15/40] Dc=17mm Lc=34mm Da=8mm La=25mm Ztip=43mm Dbi=11mm → alim=4.13mm K=7.31MN/m m=4310g
#   [16/40] Dc=30mm Lc=155mm Da=9mm La=102mm Ztip=50mm Dbi=27mm → alim=3.43mm K=5.63MN/m m=3156g
#   [17/40] Dc=25mm Lc=117mm Da=7mm La=73mm Ztip=35mm Dbi=21mm → alim=5.00mm K=6.80MN/m m=3625g
#   [18/40] Dc=29mm Lc=162mm Da=9mm La=96mm Ztip=43mm Dbi=27mm → alim=4.26mm K=5.73MN/m m=3131g
#   [19/40] Dc=13mm Lc=33mm Da=10mm La=20mm Ztip=39mm Dbi=10mm → alim=4.84mm K=7.32MN/m m=4373g
#   [20/40] Dc=22mm Lc=65mm Da=9mm La=65mm Ztip=55mm Dbi=22mm → alim=5.00mm K=6.83MN/m m=3757g
#   [21/40] Dc=24mm Lc=65mm Da=9mm La=65mm Ztip=56mm Dbi=19mm → alim=5.00mm K=6.96MN/m m=3845g
#   [22/40] Dc=25mm Lc=51mm Da=8mm La=14mm Ztip=34mm Dbi=22mm → alim=3.07mm K=6.83MN/m m=3597g
#   [23/40] Dc=18mm Lc=35mm Da=8mm La=35mm Ztip=50mm Dbi=18mm → alim=4.65mm K=7.13MN/m m=4008g
#   [24/40] Dc=23mm Lc=64mm Da=9mm La=57mm Ztip=51mm Dbi=20mm → alim=5.00mm K=6.99MN/m m=3852g
#   [25/40] Dc=17mm Lc=66mm Da=6mm La=40mm Ztip=36mm Dbi=17mm → alim=3.74mm K=7.15MN/m m=4002g
#   [26/40] Dc=21mm Lc=139mm Da=13mm La=68mm Ztip=66mm Dbi=20mm → alim=2.10mm K=6.94MN/m m=3972g
#   [27/40] Dc=11mm Lc=34mm Da=7mm La=25mm Ztip=35mm Dbi=10mm → alim=4.04mm K=7.33MN/m m=4382g
#   [28/40] Dc=27mm Lc=117mm Da=8mm La=73mm Ztip=55mm Dbi=22mm → alim=4.11mm K=6.51MN/m m=3538g
#   [29/40] Dc=12mm Lc=38mm Da=8mm La=38mm Ztip=50mm Dbi=12mm → alim=4.04mm K=7.30MN/m m=4309g
#   [30/40] Dc=18mm Lc=36mm Da=11mm La=36mm Ztip=51mm Dbi=18mm → alim=5.00mm K=7.12MN/m m=4027g
#   [31/40] Dc=10mm Lc=26mm Da=8mm La=17mm Ztip=44mm Dbi=10mm → alim=3.10mm K=7.33MN/m m=4374g
#   [32/40] Dc=15mm Lc=55mm Da=15mm La=38mm Ztip=53mm Dbi=13mm → alim=5.00mm K=7.29MN/m m=4355g
#   [33/40] Dc=11mm Lc=42mm Da=7mm La=8mm Ztip=35mm Dbi=11mm → alim=2.68mm K=7.32MN/m m=4350g
#   [34/40] Dc=24mm Lc=116mm Da=9mm La=72mm Ztip=44mm Dbi=21mm → alim=5.00mm K=6.79MN/m m=3684g
#   [35/40] Dc=18mm Lc=80mm Da=6mm La=67mm Ztip=35mm Dbi=17mm → alim=4.07mm K=7.14MN/m m=3991g
#   [36/40] Dc=23mm Lc=117mm Da=7mm La=73mm Ztip=56mm Dbi=22mm → alim=3.54mm K=6.76MN/m m=3693g
#   [37/40] Dc=16mm Lc=27mm Da=7mm La=18mm Ztip=43mm Dbi=13mm → alim=3.78mm K=7.28MN/m m=4240g
#   [38/40] Dc=18mm Lc=41mm Da=16mm La=35mm Ztip=51mm Dbi=18mm → alim=5.00mm K=7.12MN/m m=4091g
#   [39/40] Dc=20mm Lc=65mm Da=6mm La=63mm Ztip=36mm Dbi=19mm → alim=3.43mm K=7.03MN/m m=3847g
#   [40/40] Dc=23mm Lc=67mm Da=9mm La=66mm Ztip=56mm Dbi=20mm → alim=4.69mm K=6.96MN/m m=3857g
# Gen  3/20 | best alim=5.00mm  best K=7.33MN/m  min m=3126g  |Pareto|=57
# Gen 4/20 — evaluating 40 offspring...
#   [ 1/40] Dc=22mm Lc=50mm Da=9mm La=11mm Ztip=49mm Dbi=22mm → alim=2.74mm K=6.87MN/m m=3717g
#   [ 2/40] Dc=29mm Lc=65mm Da=18mm La=65mm Ztip=67mm Dbi=26mm → alim=3.26mm K=6.14MN/m m=3558g
#   [ 3/40] Dc=11mm Lc=25mm Da=8mm La=18mm Ztip=35mm Dbi=10mm → alim=4.67mm K=7.33MN/m m=4376g
#   [ 4/40] Dc=25mm Lc=118mm Da=8mm La=71mm Ztip=45mm Dbi=21mm → alim=5.00mm K=6.74MN/m m=3634g
#   [ 5/40] Dc=11mm Lc=29mm Da=8mm La=17mm Ztip=43mm Dbi=11mm → alim=2.76mm K=7.32MN/m m=4360g
#   [ 6/40] Dc=29mm Lc=151mm Da=9mm La=96mm Ztip=44mm Dbi=26mm → alim=4.44mm K=5.91MN/m m=3211g
#   [ 7/40] Dc=10mm Lc=26mm Da=8mm La=17mm Ztip=44mm Dbi=10mm → alim=3.85mm K=7.33MN/m m=4376g
#   [ 8/40] Dc=29mm Lc=162mm Da=9mm La=96mm Ztip=43mm Dbi=27mm → alim=4.25mm K=5.73MN/m m=3131g
#   [ 9/40] Dc=10mm Lc=34mm Da=10mm La=6mm Ztip=44mm Dbi=10mm → alim=3.28mm K=7.33MN/m m=4375g
#   [10/40] Dc=11mm Lc=40mm Da=10mm La=23mm Ztip=50mm Dbi=11mm → alim=5.00mm K=7.32MN/m m=4393g
#   [11/40] Dc=24mm Lc=117mm Da=7mm La=73mm Ztip=39mm Dbi=22mm → alim=4.51mm K=6.75MN/m m=3608g
#   [12/40] Dc=29mm Lc=162mm Da=9mm La=96mm Ztip=36mm Dbi=29mm → alim=4.25mm K=5.59MN/m m=2970g
#   [13/40] Dc=10mm Lc=43mm Da=7mm La=24mm Ztip=33mm Dbi=10mm → alim=4.28mm K=7.33MN/m m=4378g
#   [14/40] Dc=29mm Lc=155mm Da=9mm La=97mm Ztip=43mm Dbi=27mm → alim=4.21mm K=5.80MN/m m=3149g
#   [15/40] Dc=24mm Lc=117mm Da=7mm La=73mm Ztip=35mm Dbi=22mm → alim=5.00mm K=6.76MN/m m=3593g
#   [16/40] Dc=24mm Lc=121mm Da=7mm La=73mm Ztip=35mm Dbi=22mm → alim=5.00mm K=6.75MN/m m=3589g
#   [17/40] Dc=17mm Lc=64mm Da=6mm La=39mm Ztip=35mm Dbi=17mm → alim=4.06mm K=7.15MN/m m=3996g
#   [18/40] Dc=24mm Lc=119mm Da=7mm La=74mm Ztip=36mm Dbi=22mm → alim=4.95mm K=6.76MN/m m=3602g
#   [19/40] Dc=18mm Lc=25mm Da=6mm La=20mm Ztip=56mm Dbi=11mm → alim=2.60mm K=7.32MN/m m=4334g
#   [20/40] Dc=27mm Lc=146mm Da=9mm La=109mm Ztip=59mm Dbi=26mm → alim=3.15mm K=6.24MN/m m=3437g
#   [21/40] Dc=24mm Lc=117mm Da=7mm La=73mm Ztip=35mm Dbi=22mm → alim=4.98mm K=6.76MN/m m=3593g
#   [22/40] Dc=24mm Lc=117mm Da=7mm La=73mm Ztip=35mm Dbi=22mm → alim=5.00mm K=6.76MN/m m=3593g
#   [23/40] Dc=20mm Lc=41mm Da=14mm La=5mm Ztip=48mm Dbi=18mm → alim=3.73mm K=7.13MN/m m=3986g
#   [24/40] Dc=21mm Lc=67mm Da=6mm La=63mm Ztip=36mm Dbi=20mm → alim=3.80mm K=6.99MN/m m=3800g
#   [25/40] Dc=15mm Lc=37mm Da=6mm La=36mm Ztip=33mm Dbi=15mm → alim=4.57mm K=7.24MN/m m=4148g
#   [26/40] Dc=20mm Lc=63mm Da=7mm La=40mm Ztip=36mm Dbi=18mm → alim=4.76mm K=7.12MN/m m=3938g
#   [27/40] Dc=24mm Lc=117mm Da=7mm La=73mm Ztip=35mm Dbi=21mm → alim=4.99mm K=6.78MN/m m=3612g
#   [28/40] Dc=29mm Lc=49mm Da=18mm La=12mm Ztip=49mm Dbi=26mm → alim=5.00mm K=6.20MN/m m=3274g
#   [29/40] Dc=24mm Lc=120mm Da=7mm La=73mm Ztip=39mm Dbi=22mm → alim=4.02mm K=6.73MN/m m=3594g
#   [30/40] Dc=31mm Lc=152mm Da=9mm La=96mm Ztip=43mm Dbi=27mm → alim=5.00mm K=5.52MN/m m=3033g
#   [31/40] Dc=11mm Lc=25mm Da=9mm La=14mm Ztip=45mm Dbi=10mm → alim=4.18mm K=7.33MN/m m=4379g
#   [32/40] Dc=15mm Lc=55mm Da=15mm La=40mm Ztip=53mm Dbi=15mm → alim=5.00mm K=7.23MN/m m=4248g
#   [33/40] Dc=10mm Lc=27mm Da=6mm La=11mm Ztip=43mm Dbi=10mm → alim=2.53mm K=7.33MN/m m=4375g
#   [34/40] Dc=18mm Lc=82mm Da=8mm La=73mm Ztip=44mm Dbi=17mm → alim=4.40mm K=7.15MN/m m=4050g
#   [35/40] Dc=17mm Lc=27mm Da=6mm La=27mm Ztip=51mm Dbi=11mm → alim=3.65mm K=7.32MN/m m=4338g
#   [36/40] Dc=14mm Lc=139mm Da=12mm La=41mm Ztip=66mm Dbi=14mm → alim=3.96mm K=7.28MN/m m=4318g
#   [37/40] Dc=19mm Lc=34mm Da=9mm La=12mm Ztip=32mm Dbi=19mm → alim=3.49mm K=7.03MN/m m=3837g
#   [38/40] Dc=29mm Lc=49mm Da=18mm La=32mm Ztip=50mm Dbi=26mm → alim=5.00mm K=6.32MN/m m=3417g
#   [39/40] Dc=17mm Lc=21mm Da=6mm La=21mm Ztip=50mm Dbi=10mm → alim=2.29mm K=7.32MN/m m=4344g
#   [40/40] Dc=11mm Lc=34mm Da=11mm La=23mm Ztip=49mm Dbi=11mm → alim=4.95mm K=7.32MN/m m=4393g
# Gen  4/20 | best alim=5.00mm  best K=7.33MN/m  min m=2970g  |Pareto|=60
# Gen 5/20 — evaluating 40 offspring...
#   [ 1/40] Dc=27mm Lc=43mm Da=8mm La=13mm Ztip=49mm Dbi=22mm → alim=3.12mm K=6.78MN/m m=3603g
#   [ 2/40] Dc=29mm Lc=125mm Da=18mm La=72mm Ztip=54mm Dbi=26mm → alim=2.51mm K=6.00MN/m m=3465g
#   [ 3/40] Dc=11mm Lc=38mm Da=9mm La=6mm Ztip=44mm Dbi=10mm → alim=2.59mm K=7.33MN/m m=4374g
#   [ 4/40] Dc=29mm Lc=146mm Da=10mm La=96mm Ztip=53mm Dbi=26mm → alim=2.58mm K=5.91MN/m m=3290g
#   [ 5/40] Dc=12mm Lc=37mm Da=9mm La=37mm Ztip=36mm Dbi=11mm → alim=5.00mm K=7.32MN/m m=4368g
#   [ 6/40] Dc=28mm Lc=152mm Da=9mm La=96mm Ztip=53mm Dbi=28mm → alim=4.14mm K=5.98MN/m m=3250g
#   [ 7/40] Dc=14mm Lc=22mm Da=6mm La=11mm Ztip=36mm Dbi=11mm → alim=2.66mm K=7.32MN/m m=4322g
#   [ 8/40] Dc=29mm Lc=145mm Da=9mm La=108mm Ztip=60mm Dbi=28mm → alim=4.01mm K=5.70MN/m m=3186g
#   [ 9/40] Dc=20mm Lc=49mm Da=7mm La=32mm Ztip=37mm Dbi=18mm → alim=4.17mm K=7.12MN/m m=3941g
#   [10/40] Dc=29mm Lc=63mm Da=17mm La=40mm Ztip=49mm Dbi=26mm → alim=4.58mm K=6.31MN/m m=3429g
#   [11/40] Dc=18mm Lc=85mm Da=9mm La=73mm Ztip=35mm Dbi=17mm → alim=3.19mm K=7.15MN/m m=4054g
#   [12/40] Dc=24mm Lc=119mm Da=8mm La=61mm Ztip=43mm Dbi=22mm → alim=4.42mm K=6.74MN/m m=3613g
#   [13/40] Dc=21mm Lc=63mm Da=6mm La=63mm Ztip=35mm Dbi=17mm → alim=4.64mm K=7.14MN/m m=3949g
#   [14/40] Dc=24mm Lc=124mm Da=7mm La=90mm Ztip=36mm Dbi=22mm → alim=4.91mm K=6.75MN/m m=3610g
#   [15/40] Dc=24mm Lc=123mm Da=7mm La=74mm Ztip=35mm Dbi=22mm → alim=4.71mm K=6.73MN/m m=3577g
#   [16/40] Dc=30mm Lc=150mm Da=9mm La=95mm Ztip=43mm Dbi=27mm → alim=3.80mm K=5.56MN/m m=3047g
#   [17/40] Dc=10mm Lc=45mm Da=8mm La=24mm Ztip=33mm Dbi=10mm → alim=3.87mm K=7.33MN/m m=4387g
#   [18/40] Dc=30mm Lc=154mm Da=9mm La=96mm Ztip=43mm Dbi=26mm → alim=4.42mm K=5.70MN/m m=3121g
#   [19/40] Dc=21mm Lc=68mm Da=6mm La=67mm Ztip=36mm Dbi=20mm → alim=4.51mm K=7.01MN/m m=3818g
#   [20/40] Dc=29mm Lc=150mm Da=10mm La=63mm Ztip=44mm Dbi=26mm → alim=3.43mm K=5.94MN/m m=3192g
#   [21/40] Dc=16mm Lc=22mm Da=5mm La=14mm Ztip=34mm Dbi=15mm → alim=3.00mm K=7.24MN/m m=4131g
#   [22/40] Dc=24mm Lc=119mm Da=6mm La=74mm Ztip=42mm Dbi=23mm → alim=3.73mm K=6.68MN/m m=3557g
#   [23/40] Dc=29mm Lc=151mm Da=9mm La=88mm Ztip=46mm Dbi=26mm → alim=4.35mm K=5.91MN/m m=3214g
#   [24/40] Dc=31mm Lc=155mm Da=9mm La=74mm Ztip=50mm Dbi=27mm → alim=3.32mm K=5.44MN/m m=3044g
#   [25/40] Dc=15mm Lc=25mm Da=6mm La=25mm Ztip=34mm Dbi=15mm → alim=3.18mm K=7.24MN/m m=4145g
#   [26/40] Dc=29mm Lc=163mm Da=9mm La=99mm Ztip=42mm Dbi=27mm → alim=3.80mm K=5.76MN/m m=3139g
#   [27/40] Dc=29mm Lc=155mm Da=9mm La=96mm Ztip=43mm Dbi=26mm → alim=3.84mm K=5.89MN/m m=3202g
#   [28/40] Dc=31mm Lc=152mm Da=9mm La=97mm Ztip=44mm Dbi=27mm → alim=4.19mm K=5.49MN/m m=3033g
#   [29/40] Dc=13mm Lc=27mm Da=6mm La=13mm Ztip=43mm Dbi=10mm → alim=2.03mm K=7.33MN/m m=4364g
#   [30/40] Dc=30mm Lc=143mm Da=11mm La=101mm Ztip=62mm Dbi=28mm → alim=1.77mm K=5.65MN/m m=3240g
#   [31/40] Dc=11mm Lc=44mm Da=6mm La=12mm Ztip=33mm Dbi=10mm → alim=1.22mm K=7.33MN/m m=4356g
#   [32/40] Dc=28mm Lc=50mm Da=19mm La=25mm Ztip=49mm Dbi=26mm → alim=5.00mm K=6.28MN/m m=3380g
#   [33/40] Dc=20mm Lc=43mm Da=9mm La=5mm Ztip=43mm Dbi=18mm → alim=2.73mm K=7.11MN/m m=3933g
#   [34/40] Dc=29mm Lc=153mm Da=14mm La=96mm Ztip=48mm Dbi=26mm → alim=2.08mm K=5.89MN/m m=3377g
#   [35/40] Dc=29mm Lc=49mm Da=9mm La=18mm Ztip=43mm Dbi=26mm → alim=3.74mm K=6.21MN/m m=3221g
#   [36/40] Dc=32mm Lc=152mm Da=18mm La=92mm Ztip=48mm Dbi=27mm → alim=1.96mm K=4.96MN/m m=3188g
#   [37/40] Dc=29mm Lc=49mm Da=20mm La=32mm Ztip=50mm Dbi=26mm → alim=4.89mm K=6.32MN/m m=3457g
#   [38/40] Dc=10mm Lc=54mm Da=7mm La=54mm Ztip=53mm Dbi=10mm → alim=3.98mm K=7.33MN/m m=4408g
#   [39/40] Dc=20mm Lc=33mm Da=8mm La=27mm Ztip=43mm Dbi=10mm → alim=4.20mm K=7.32MN/m m=4318g
#   [40/40] Dc=29mm Lc=152mm Da=9mm La=93mm Ztip=44mm Dbi=26mm → alim=4.60mm K=5.90MN/m m=3200g
# Gen  5/20 | best alim=5.00mm  best K=7.33MN/m  min m=2970g  |Pareto|=63
# Gen 6/20 — evaluating 40 offspring...
#   [ 1/40] Dc=27mm Lc=119mm Da=8mm La=74mm Ztip=49mm Dbi=22mm → alim=4.10mm K=6.53MN/m m=3522g
#   [ 2/40] Dc=28mm Lc=150mm Da=9mm La=95mm Ztip=55mm Dbi=28mm → alim=3.96mm K=5.91MN/m m=3235g
#   [ 3/40] Dc=22mm Lc=50mm Da=9mm La=11mm Ztip=49mm Dbi=22mm → alim=3.05mm K=6.87MN/m m=3715g
#   [ 4/40] Dc=29mm Lc=168mm Da=10mm La=89mm Ztip=36mm Dbi=29mm → alim=5.00mm K=5.59MN/m m=2988g
#   [ 5/40] Dc=13mm Lc=26mm Da=7mm La=13mm Ztip=42mm Dbi=11mm → alim=1.41mm K=7.32MN/m m=4332g
#   [ 6/40] Dc=29mm Lc=41mm Da=17mm La=32mm Ztip=50mm Dbi=25mm → alim=5.00mm K=6.46MN/m m=3486g
#   [ 7/40] Dc=16mm Lc=23mm Da=5mm La=11mm Ztip=43mm Dbi=15mm → alim=1.51mm K=7.23MN/m m=4120g
#   [ 8/40] Dc=29mm Lc=160mm Da=9mm La=99mm Ztip=45mm Dbi=27mm → alim=4.24mm K=5.76MN/m m=3143g
#   [ 9/40] Dc=16mm Lc=21mm Da=5mm La=13mm Ztip=34mm Dbi=15mm → alim=2.24mm K=7.24MN/m m=4133g
#   [10/40] Dc=28mm Lc=151mm Da=10mm La=63mm Ztip=44mm Dbi=26mm → alim=4.21mm K=5.99MN/m m=3211g
#   [11/40] Dc=21mm Lc=48mm Da=6mm La=32mm Ztip=36mm Dbi=21mm → alim=3.95mm K=6.91MN/m m=3721g
#   [12/40] Dc=28mm Lc=67mm Da=17mm La=63mm Ztip=49mm Dbi=26mm → alim=4.31mm K=6.29MN/m m=3513g
#   [13/40] Dc=11mm Lc=34mm Da=7mm La=24mm Ztip=33mm Dbi=10mm → alim=4.26mm K=7.33MN/m m=4382g
#   [14/40] Dc=19mm Lc=51mm Da=8mm La=25mm Ztip=43mm Dbi=11mm → alim=3.39mm K=7.31MN/m m=4280g
#   [15/40] Dc=10mm Lc=40mm Da=8mm La=23mm Ztip=32mm Dbi=10mm → alim=4.91mm K=7.33MN/m m=4379g
#   [16/40] Dc=20mm Lc=34mm Da=10mm La=34mm Ztip=51mm Dbi=18mm → alim=5.00mm K=7.09MN/m m=3974g
#   [17/40] Dc=13mm Lc=45mm Da=6mm La=13mm Ztip=35mm Dbi=11mm → alim=2.55mm K=7.32MN/m m=4331g
#   [18/40] Dc=26mm Lc=150mm Da=9mm La=92mm Ztip=44mm Dbi=26mm → alim=4.78mm K=6.28MN/m m=3364g
#   [19/40] Dc=22mm Lc=64mm Da=6mm La=63mm Ztip=41mm Dbi=19mm → alim=4.09mm K=7.02MN/m m=3829g
#   [20/40] Dc=27mm Lc=152mm Da=9mm La=104mm Ztip=53mm Dbi=27mm → alim=3.47mm K=6.05MN/m m=3298g
#   [21/40] Dc=19mm Lc=36mm Da=6mm La=34mm Ztip=33mm Dbi=19mm → alim=4.06mm K=7.08MN/m m=3886g
#   [22/40] Dc=22mm Lc=66mm Da=8mm La=66mm Ztip=36mm Dbi=19mm → alim=5.00mm K=7.01MN/m m=3833g
#   [23/40] Dc=16mm Lc=20mm Da=5mm La=14mm Ztip=30mm Dbi=15mm → alim=3.03mm K=7.24MN/m m=4131g
#   [24/40] Dc=24mm Lc=51mm Da=7mm La=14mm Ztip=34mm Dbi=22mm → alim=3.38mm K=6.83MN/m m=3615g
#   [25/40] Dc=21mm Lc=49mm Da=5mm La=11mm Ztip=35mm Dbi=17mm → alim=2.17mm K=7.15MN/m m=3943g
#   [26/40] Dc=29mm Lc=69mm Da=18mm La=64mm Ztip=48mm Dbi=26mm → alim=4.82mm K=6.18MN/m m=3471g
#   [27/40] Dc=28mm Lc=152mm Da=9mm La=96mm Ztip=43mm Dbi=26mm → alim=4.63mm K=6.06MN/m m=3258g
#   [28/40] Dc=30mm Lc=152mm Da=9mm La=94mm Ztip=53mm Dbi=28mm → alim=3.53mm K=5.59MN/m m=3110g
#   [29/40] Dc=10mm Lc=45mm Da=7mm La=14mm Ztip=33mm Dbi=10mm → alim=3.59mm K=7.33MN/m m=4368g
#   [30/40] Dc=22mm Lc=71mm Da=8mm La=24mm Ztip=34mm Dbi=22mm → alim=3.40mm K=6.81MN/m m=3625g
#   [31/40] Dc=10mm Lc=29mm Da=6mm La=11mm Ztip=36mm Dbi=10mm → alim=1.10mm K=7.33MN/m m=4375g
#   [32/40] Dc=20mm Lc=65mm Da=6mm La=63mm Ztip=38mm Dbi=20mm → alim=4.43mm K=6.97MN/m m=3799g
#   [33/40] Dc=21mm Lc=66mm Da=6mm La=58mm Ztip=41mm Dbi=21mm → alim=4.04mm K=6.92MN/m m=3752g
#   [34/40] Dc=27mm Lc=118mm Da=8mm La=73mm Ztip=55mm Dbi=22mm → alim=3.75mm K=6.50MN/m m=3538g
#   [35/40] Dc=11mm Lc=29mm Da=7mm La=24mm Ztip=36mm Dbi=11mm → alim=4.32mm K=7.32MN/m m=4342g
#   [36/40] Dc=24mm Lc=122mm Da=11mm La=72mm Ztip=49mm Dbi=20mm → alim=4.55mm K=6.83MN/m m=3780g
#   [37/40] Dc=11mm Lc=44mm Da=6mm La=12mm Ztip=33mm Dbi=10mm → alim=2.58mm K=7.33MN/m m=4356g
#   [38/40] Dc=11mm Lc=45mm Da=5mm La=13mm Ztip=33mm Dbi=10mm → alim=2.52mm K=7.33MN/m m=4355g
#   [39/40] Dc=11mm Lc=28mm Da=6mm La=13mm Ztip=34mm Dbi=10mm → alim=2.93mm K=7.33MN/m m=4370g
#   [40/40] Dc=17mm Lc=44mm Da=6mm La=27mm Ztip=49mm Dbi=10mm → alim=3.18mm K=7.31MN/m m=4312g
# Gen  6/20 | best alim=5.00mm  best K=7.33MN/m  min m=2970g  |Pareto|=64
# Gen 7/20 — evaluating 40 offspring...
#   [ 1/40] Dc=19mm Lc=36mm Da=6mm La=34mm Ztip=33mm Dbi=18mm → alim=4.40mm K=7.12MN/m m=3938g
#   [ 2/40] Dc=24mm Lc=117mm Da=7mm La=73mm Ztip=33mm Dbi=21mm → alim=5.00mm K=6.81MN/m m=3624g
#   [ 3/40] Dc=20mm Lc=61mm Da=6mm La=61mm Ztip=36mm Dbi=20mm → alim=5.00mm K=6.99MN/m m=3811g
#   [ 4/40] Dc=29mm Lc=167mm Da=9mm La=96mm Ztip=38mm Dbi=29mm → alim=4.38mm K=5.76MN/m m=3059g
#   [ 5/40] Dc=10mm Lc=44mm Da=8mm La=24mm Ztip=32mm Dbi=10mm → alim=4.01mm K=7.33MN/m m=4382g
#   [ 6/40] Dc=29mm Lc=51mm Da=17mm La=33mm Ztip=50mm Dbi=25mm → alim=5.00mm K=6.34MN/m m=3416g
#   [ 7/40] Dc=15mm Lc=26mm Da=6mm La=18mm Ztip=41mm Dbi=14mm → alim=3.05mm K=7.28MN/m m=4216g
#   [ 8/40] Dc=21mm Lc=67mm Da=7mm La=58mm Ztip=43mm Dbi=20mm → alim=5.00mm K=6.95MN/m m=3792g
#   [ 9/40] Dc=10mm Lc=31mm Da=6mm La=25mm Ztip=42mm Dbi=10mm → alim=3.22mm K=7.32MN/m m=4367g
#   [10/40] Dc=24mm Lc=122mm Da=11mm La=72mm Ztip=49mm Dbi=20mm → alim=4.61mm K=6.81MN/m m=3770g
#   [11/40] Dc=19mm Lc=37mm Da=6mm La=35mm Ztip=32mm Dbi=19mm → alim=4.25mm K=7.06MN/m m=3867g
#   [12/40] Dc=24mm Lc=119mm Da=5mm La=72mm Ztip=35mm Dbi=23mm → alim=3.65mm K=6.69MN/m m=3521g
#   [13/40] Dc=15mm Lc=27mm Da=6mm La=19mm Ztip=34mm Dbi=13mm → alim=3.56mm K=7.28MN/m m=4209g
#   [14/40] Dc=21mm Lc=36mm Da=7mm La=33mm Ztip=43mm Dbi=18mm → alim=4.75mm K=7.09MN/m m=3922g
#   [15/40] Dc=10mm Lc=27mm Da=9mm La=16mm Ztip=40mm Dbi=10mm → alim=3.29mm K=7.33MN/m m=4383g
#   [16/40] Dc=16mm Lc=53mm Da=15mm La=39mm Ztip=52mm Dbi=16mm → alim=5.00mm K=7.22MN/m m=4235g
#   [17/40] Dc=10mm Lc=32mm Da=9mm La=25mm Ztip=35mm Dbi=10mm → alim=5.00mm K=7.33MN/m m=4386g
#   [18/40] Dc=19mm Lc=86mm Da=11mm La=71mm Ztip=50mm Dbi=17mm → alim=5.00mm K=7.14MN/m m=4084g
#   [19/40] Dc=11mm Lc=23mm Da=6mm La=13mm Ztip=36mm Dbi=10mm → alim=3.03mm K=7.33MN/m m=4370g
#   [20/40] Dc=28mm Lc=168mm Da=9mm La=95mm Ztip=36mm Dbi=28mm → alim=4.50mm K=5.84MN/m m=3090g
#   [21/40] Dc=24mm Lc=122mm Da=6mm La=73mm Ztip=37mm Dbi=24mm → alim=3.66mm K=6.61MN/m m=3487g
#   [22/40] Dc=29mm Lc=159mm Da=9mm La=96mm Ztip=42mm Dbi=29mm → alim=4.39mm K=5.58MN/m m=3002g
#   [23/40] Dc=12mm Lc=31mm Da=6mm La=14mm Ztip=36mm Dbi=10mm → alim=2.62mm K=7.33MN/m m=4358g
#   [24/40] Dc=28mm Lc=160mm Da=9mm La=94mm Ztip=36mm Dbi=28mm → alim=4.94mm K=5.99MN/m m=3163g
#   [25/40] Dc=16mm Lc=28mm Da=5mm La=14mm Ztip=46mm Dbi=14mm → alim=2.62mm K=7.27MN/m m=4210g
#   [26/40] Dc=23mm Lc=111mm Da=6mm La=74mm Ztip=45mm Dbi=23mm → alim=3.53mm K=6.68MN/m m=3568g
#   [27/40] Dc=21mm Lc=52mm Da=9mm La=13mm Ztip=36mm Dbi=21mm → alim=3.65mm K=6.92MN/m m=3724g
#   [28/40] Dc=28mm Lc=156mm Da=9mm La=94mm Ztip=49mm Dbi=28mm → alim=4.26mm K=5.85MN/m m=3162g
#   [29/40] Dc=11mm Lc=54mm Da=9mm La=54mm Ztip=43mm Dbi=10mm → alim=5.00mm K=7.33MN/m m=4411g
#   [30/40] Dc=27mm Lc=152mm Da=9mm La=95mm Ztip=53mm Dbi=27mm → alim=4.11mm K=6.05MN/m m=3288g
#   [31/40] Dc=10mm Lc=34mm Da=5mm La=11mm Ztip=34mm Dbi=10mm → alim=1.15mm K=7.33MN/m m=4367g
#   [32/40] Dc=21mm Lc=53mm Da=11mm La=28mm Ztip=50mm Dbi=16mm → alim=4.99mm K=7.18MN/m m=4067g
#   [33/40] Dc=16mm Lc=23mm Da=7mm La=13mm Ztip=36mm Dbi=13mm → alim=3.54mm K=7.28MN/m m=4213g
#   [34/40] Dc=29mm Lc=162mm Da=9mm La=99mm Ztip=43mm Dbi=29mm → alim=4.00mm K=5.60MN/m m=3033g
#   [35/40] Dc=10mm Lc=40mm Da=7mm La=26mm Ztip=32mm Dbi=10mm → alim=3.59mm K=7.33MN/m m=4381g
#   [36/40] Dc=28mm Lc=156mm Da=9mm La=96mm Ztip=44mm Dbi=26mm → alim=4.53mm K=6.09MN/m m=3297g
#   [37/40] Dc=12mm Lc=47mm Da=9mm La=47mm Ztip=35mm Dbi=12mm → alim=5.00mm K=7.31MN/m m=4330g
#   [38/40] Dc=28mm Lc=151mm Da=9mm La=99mm Ztip=54mm Dbi=28mm → alim=3.83mm K=5.98MN/m m=3267g
#   [39/40] Dc=15mm Lc=23mm Da=7mm La=18mm Ztip=35mm Dbi=13mm → alim=3.23mm K=7.29MN/m m=4239g
#   [40/40] Dc=25mm Lc=121mm Da=7mm La=83mm Ztip=43mm Dbi=22mm → alim=2.73mm K=6.68MN/m m=3585g
# Gen  7/20 | best alim=5.00mm  best K=7.33MN/m  min m=2970g  |Pareto|=57
# Gen 8/20 — evaluating 40 offspring...
#   [ 1/40] Dc=19mm Lc=51mm Da=8mm La=24mm Ztip=37mm Dbi=11mm → alim=3.94mm K=7.31MN/m m=4272g
#   [ 2/40] Dc=29mm Lc=162mm Da=9mm La=97mm Ztip=43mm Dbi=29mm → alim=4.29mm K=5.78MN/m m=3096g
#   [ 3/40] Dc=11mm Lc=36mm Da=5mm La=12mm Ztip=36mm Dbi=11mm → alim=2.10mm K=7.32MN/m m=4328g
#   [ 4/40] Dc=28mm Lc=165mm Da=10mm La=88mm Ztip=36mm Dbi=28mm → alim=3.49mm K=5.85MN/m m=3098g
#   [ 5/40] Dc=16mm Lc=26mm Da=5mm La=9mm Ztip=35mm Dbi=15mm → alim=2.05mm K=7.23MN/m m=4106g
#   [ 6/40] Dc=18mm Lc=82mm Da=9mm La=75mm Ztip=43mm Dbi=17mm → alim=5.00mm K=7.15MN/m m=4070g
#   [ 7/40] Dc=13mm Lc=25mm Da=6mm La=14mm Ztip=46mm Dbi=10mm → alim=2.70mm K=7.32MN/m m=4354g
#   [ 8/40] Dc=24mm Lc=121mm Da=6mm La=73mm Ztip=43mm Dbi=22mm → alim=3.19mm K=6.71MN/m m=3585g
#   [ 9/40] Dc=29mm Lc=41mm Da=17mm La=31mm Ztip=50mm Dbi=25mm → alim=5.00mm K=6.48MN/m m=3495g
#   [10/40] Dc=28mm Lc=51mm Da=17mm La=33mm Ztip=50mm Dbi=25mm → alim=5.00mm K=6.35MN/m m=3433g
#   [11/40] Dc=10mm Lc=37mm Da=6mm La=23mm Ztip=32mm Dbi=10mm → alim=3.68mm K=7.33MN/m m=4364g
#   [12/40] Dc=19mm Lc=43mm Da=9mm La=36mm Ztip=33mm Dbi=19mm → alim=5.00mm K=7.08MN/m m=3917g
#   [13/40] Dc=13mm Lc=27mm Da=6mm La=11mm Ztip=36mm Dbi=11mm → alim=2.85mm K=7.32MN/m m=4330g
#   [14/40] Dc=20mm Lc=61mm Da=6mm La=61mm Ztip=37mm Dbi=19mm → alim=3.77mm K=7.04MN/m m=3859g
#   [15/40] Dc=21mm Lc=49mm Da=5mm La=11mm Ztip=35mm Dbi=17mm → alim=2.53mm K=7.16MN/m m=3960g
#   [16/40] Dc=29mm Lc=168mm Da=10mm La=89mm Ztip=36mm Dbi=29mm → alim=2.61mm K=5.59MN/m m=2988g
#   [17/40] Dc=13mm Lc=26mm Da=5mm La=11mm Ztip=36mm Dbi=10mm → alim=2.60mm K=7.32MN/m m=4345g
#   [18/40] Dc=21mm Lc=50mm Da=6mm La=6mm Ztip=43mm Dbi=17mm → alim=1.13mm K=7.16MN/m m=3981g
#   [19/40] Dc=11mm Lc=32mm Da=6mm La=12mm Ztip=36mm Dbi=10mm → alim=2.73mm K=7.33MN/m m=4368g
#   [20/40] Dc=27mm Lc=165mm Da=9mm La=95mm Ztip=36mm Dbi=27mm → alim=4.42mm K=6.04MN/m m=3193g
#   [21/40] Dc=16mm Lc=23mm Da=5mm La=11mm Ztip=43mm Dbi=15mm → alim=2.16mm K=7.23MN/m m=4120g
#   [22/40] Dc=20mm Lc=61mm Da=6mm La=61mm Ztip=36mm Dbi=20mm → alim=5.00mm K=6.99MN/m m=3811g
#   [23/40] Dc=21mm Lc=49mm Da=5mm La=11mm Ztip=34mm Dbi=17mm → alim=2.38mm K=7.14MN/m m=3938g
#   [24/40] Dc=22mm Lc=50mm Da=9mm La=17mm Ztip=49mm Dbi=21mm → alim=3.44mm K=6.93MN/m m=3778g
#   [25/40] Dc=20mm Lc=62mm Da=6mm La=62mm Ztip=36mm Dbi=20mm → alim=3.23mm K=6.99MN/m m=3818g
#   [26/40] Dc=28mm Lc=168mm Da=9mm La=98mm Ztip=36mm Dbi=28mm → alim=3.56mm K=5.83MN/m m=3095g
#   [27/40] Dc=11mm Lc=37mm Da=7mm La=24mm Ztip=31mm Dbi=10mm → alim=4.64mm K=7.33MN/m m=4368g
#   [28/40] Dc=24mm Lc=123mm Da=7mm La=74mm Ztip=35mm Dbi=22mm → alim=5.00mm K=6.79MN/m m=3627g
#   [29/40] Dc=18mm Lc=49mm Da=9mm La=11mm Ztip=36mm Dbi=17mm → alim=2.22mm K=7.16MN/m m=4004g
#   [30/40] Dc=22mm Lc=86mm Da=9mm La=73mm Ztip=48mm Dbi=22mm → alim=5.00mm K=6.86MN/m m=3769g
#   [31/40] Dc=19mm Lc=49mm Da=8mm La=19mm Ztip=43mm Dbi=10mm → alim=3.81mm K=7.31MN/m m=4283g
#   [32/40] Dc=28mm Lc=153mm Da=9mm La=102mm Ztip=43mm Dbi=26mm → alim=3.77mm K=6.03MN/m m=3253g
#   [33/40] Dc=10mm Lc=41mm Da=7mm La=15mm Ztip=33mm Dbi=10mm → alim=3.19mm K=7.33MN/m m=4374g
#   [34/40] Dc=20mm Lc=87mm Da=9mm La=73mm Ztip=35mm Dbi=17mm → alim=5.00mm K=7.13MN/m m=3999g
#   [35/40] Dc=29mm Lc=162mm Da=9mm La=96mm Ztip=36mm Dbi=29mm → alim=3.12mm K=5.59MN/m m=2981g
#   [36/40] Dc=29mm Lc=162mm Da=9mm La=89mm Ztip=39mm Dbi=29mm → alim=4.01mm K=5.59MN/m m=2983g
#   [37/40] Dc=10mm Lc=33mm Da=9mm La=25mm Ztip=35mm Dbi=10mm → alim=5.00mm K=7.33MN/m m=4390g
#   [38/40] Dc=29mm Lc=166mm Da=9mm La=97mm Ztip=38mm Dbi=29mm → alim=3.82mm K=5.73MN/m m=3048g
#   [39/40] Dc=12mm Lc=28mm Da=6mm La=13mm Ztip=32mm Dbi=10mm → alim=2.99mm K=7.32MN/m m=4349g
#   [40/40] Dc=30mm Lc=163mm Da=9mm La=96mm Ztip=42mm Dbi=30mm → alim=4.22mm K=5.55MN/m m=2993g
# Gen  8/20 | best alim=5.00mm  best K=7.33MN/m  min m=2970g  |Pareto|=68
# Gen 9/20 — evaluating 40 offspring...
#   [ 1/40] Dc=27mm Lc=119mm Da=8mm La=73mm Ztip=53mm Dbi=22mm → alim=3.58mm K=6.51MN/m m=3532g
#   [ 2/40] Dc=10mm Lc=33mm Da=9mm La=25mm Ztip=34mm Dbi=10mm → alim=4.30mm K=7.33MN/m m=4388g
#   [ 3/40] Dc=22mm Lc=55mm Da=6mm La=11mm Ztip=34mm Dbi=22mm → alim=1.95mm K=6.86MN/m m=3654g
#   [ 4/40] Dc=24mm Lc=118mm Da=8mm La=73mm Ztip=47mm Dbi=24mm → alim=5.00mm K=6.62MN/m m=3570g
#   [ 5/40] Dc=11mm Lc=27mm Da=5mm La=9mm Ztip=36mm Dbi=10mm → alim=1.84mm K=7.33MN/m m=4360g
#   [ 6/40] Dc=25mm Lc=153mm Da=9mm La=95mm Ztip=44mm Dbi=25mm → alim=4.87mm K=6.39MN/m m=3434g
#   [ 7/40] Dc=18mm Lc=85mm Da=9mm La=73mm Ztip=35mm Dbi=17mm → alim=5.00mm K=7.15MN/m m=4054g
#   [ 8/40] Dc=26mm Lc=150mm Da=9mm La=92mm Ztip=43mm Dbi=26mm → alim=4.91mm K=6.28MN/m m=3357g
#   [ 9/40] Dc=15mm Lc=31mm Da=6mm La=19mm Ztip=34mm Dbi=14mm → alim=3.27mm K=7.27MN/m m=4198g
#   [10/40] Dc=24mm Lc=119mm Da=6mm La=73mm Ztip=37mm Dbi=24mm → alim=4.02mm K=6.62MN/m m=3490g
#   [11/40] Dc=20mm Lc=66mm Da=6mm La=61mm Ztip=37mm Dbi=18mm → alim=4.03mm K=7.08MN/m m=3901g
#   [12/40] Dc=29mm Lc=162mm Da=9mm La=96mm Ztip=38mm Dbi=29mm → alim=4.54mm K=5.75MN/m m=3052g
#   [13/40] Dc=10mm Lc=34mm Da=9mm La=12mm Ztip=35mm Dbi=10mm → alim=3.43mm K=7.33MN/m m=4378g
#   [14/40] Dc=18mm Lc=48mm Da=9mm La=25mm Ztip=36mm Dbi=17mm → alim=4.65mm K=7.16MN/m m=4015g
#   [15/40] Dc=27mm Lc=119mm Da=8mm La=74mm Ztip=49mm Dbi=22mm → alim=4.25mm K=6.53MN/m m=3522g
#   [16/40] Dc=22mm Lc=50mm Da=9mm La=11mm Ztip=49mm Dbi=22mm → alim=3.49mm K=6.87MN/m m=3717g
#   [17/40] Dc=18mm Lc=49mm Da=9mm La=11mm Ztip=36mm Dbi=17mm → alim=3.46mm K=7.16MN/m m=4003g
#   [18/40] Dc=18mm Lc=85mm Da=9mm La=73mm Ztip=35mm Dbi=17mm → alim=5.00mm K=7.15MN/m m=4054g
#   [19/40] Dc=13mm Lc=28mm Da=6mm La=20mm Ztip=37mm Dbi=10mm → alim=3.30mm K=7.32MN/m m=4348g
#   [20/40] Dc=31mm Lc=162mm Da=9mm La=90mm Ztip=43mm Dbi=28mm → alim=3.82mm K=5.39MN/m m=2968g
#   [21/40] Dc=13mm Lc=27mm Da=6mm La=12mm Ztip=33mm Dbi=10mm → alim=2.82mm K=7.33MN/m m=4360g
#   [22/40] Dc=15mm Lc=27mm Da=6mm La=19mm Ztip=43mm Dbi=13mm → alim=3.55mm K=7.28MN/m m=4220g
#   [23/40] Dc=12mm Lc=33mm Da=5mm La=9mm Ztip=35mm Dbi=10mm → alim=1.80mm K=7.32MN/m m=4347g
#   [24/40] Dc=27mm Lc=166mm Da=9mm La=91mm Ztip=36mm Dbi=27mm → alim=3.56mm K=6.10MN/m m=3227g
#   [25/40] Dc=10mm Lc=37mm Da=9mm La=24mm Ztip=35mm Dbi=10mm → alim=5.00mm K=7.33MN/m m=4384g
#   [26/40] Dc=29mm Lc=159mm Da=11mm La=90mm Ztip=33mm Dbi=27mm → alim=2.65mm K=5.77MN/m m=3099g
#   [27/40] Dc=16mm Lc=49mm Da=9mm La=8mm Ztip=37mm Dbi=16mm → alim=2.98mm K=7.20MN/m m=4066g
#   [28/40] Dc=25mm Lc=51mm Da=17mm La=33mm Ztip=50mm Dbi=25mm → alim=5.00mm K=6.40MN/m m=3489g
#   [29/40] Dc=22mm Lc=50mm Da=9mm La=14mm Ztip=34mm Dbi=21mm → alim=4.02mm K=6.93MN/m m=3724g
#   [30/40] Dc=28mm Lc=144mm Da=9mm La=109mm Ztip=61mm Dbi=28mm → alim=3.56mm K=5.87MN/m m=3256g
#   [31/40] Dc=18mm Lc=40mm Da=9mm La=32mm Ztip=35mm Dbi=17mm → alim=5.00mm K=7.16MN/m m=4012g
#   [32/40] Dc=27mm Lc=85mm Da=17mm La=73mm Ztip=50mm Dbi=25mm → alim=4.19mm K=6.42MN/m m=3631g
#   [33/40] Dc=10mm Lc=23mm Da=5mm La=9mm Ztip=38mm Dbi=10mm → alim=1.86mm K=7.33MN/m m=4372g
#   [34/40] Dc=28mm Lc=167mm Da=9mm La=98mm Ztip=32mm Dbi=26mm → alim=3.70mm K=6.07MN/m m=3208g
#   [35/40] Dc=10mm Lc=33mm Da=5mm La=15mm Ztip=32mm Dbi=10mm → alim=2.82mm K=7.33MN/m m=4362g
#   [36/40] Dc=19mm Lc=37mm Da=6mm La=36mm Ztip=34mm Dbi=19mm → alim=2.68mm K=7.06MN/m m=3882g
#   [37/40] Dc=10mm Lc=21mm Da=5mm La=14mm Ztip=31mm Dbi=10mm → alim=2.92mm K=7.33MN/m m=4366g
#   [38/40] Dc=16mm Lc=32mm Da=9mm La=25mm Ztip=35mm Dbi=15mm → alim=5.00mm K=7.24MN/m m=4154g
#   [39/40] Dc=10mm Lc=38mm Da=9mm La=26mm Ztip=33mm Dbi=10mm → alim=4.58mm K=7.33MN/m m=4388g
#   [40/40] Dc=27mm Lc=164mm Da=9mm La=94mm Ztip=35mm Dbi=27mm → alim=4.73mm K=6.05MN/m m=3191g
# Gen  9/20 | best alim=5.00mm  best K=7.33MN/m  min m=2968g  |Pareto|=61
# Gen 10/20 — evaluating 40 offspring...
#   [ 1/40] Dc=16mm Lc=34mm Da=6mm La=17mm Ztip=32mm Dbi=13mm → alim=2.64mm K=7.28MN/m m=4217g
#   [ 2/40] Dc=21mm Lc=47mm Da=9mm La=19mm Ztip=49mm Dbi=21mm → alim=2.97mm K=6.93MN/m m=3784g
#   [ 3/40] Dc=28mm Lc=159mm Da=10mm La=94mm Ztip=36mm Dbi=28mm → alim=2.85mm K=5.99MN/m m=3191g
#   [ 4/40] Dc=29mm Lc=162mm Da=9mm La=106mm Ztip=43mm Dbi=29mm → alim=2.78mm K=5.61MN/m m=3049g
#   [ 5/40] Dc=25mm Lc=150mm Da=9mm La=92mm Ztip=43mm Dbi=25mm → alim=4.44mm K=6.39MN/m m=3424g
#   [ 6/40] Dc=26mm Lc=153mm Da=9mm La=95mm Ztip=44mm Dbi=26mm → alim=4.71mm K=6.28MN/m m=3368g
#   [ 7/40] Dc=16mm Lc=21mm Da=5mm La=10mm Ztip=35mm Dbi=16mm → alim=2.47mm K=7.21MN/m m=4080g
#   [ 8/40] Dc=21mm Lc=49mm Da=5mm La=15mm Ztip=45mm Dbi=17mm → alim=2.44mm K=7.14MN/m m=3963g
#   [ 9/40] Dc=24mm Lc=123mm Da=7mm La=74mm Ztip=35mm Dbi=22mm → alim=3.65mm K=6.72MN/m m=3572g
#   [10/40] Dc=30mm Lc=160mm Da=9mm La=90mm Ztip=43mm Dbi=29mm → alim=3.44mm K=5.45MN/m m=2981g
#   [11/40] Dc=19mm Lc=36mm Da=6mm La=36mm Ztip=35mm Dbi=19mm → alim=3.34mm K=7.07MN/m m=3890g
#   [12/40] Dc=28mm Lc=169mm Da=9mm La=98mm Ztip=36mm Dbi=28mm → alim=5.00mm K=5.85MN/m m=3123g
#   [13/40] Dc=18mm Lc=41mm Da=6mm La=34mm Ztip=35mm Dbi=18mm → alim=4.21mm K=7.14MN/m m=3977g
#   [14/40] Dc=30mm Lc=163mm Da=9mm La=98mm Ztip=39mm Dbi=29mm → alim=4.26mm K=5.48MN/m m=2967g
#   [15/40] Dc=10mm Lc=40mm Da=7mm La=21mm Ztip=33mm Dbi=10mm → alim=3.95mm K=7.33MN/m m=4368g
#   [16/40] Dc=27mm Lc=168mm Da=9mm La=97mm Ztip=35mm Dbi=27mm → alim=3.87mm K=6.09MN/m m=3220g
#   [17/40] Dc=26mm Lc=152mm Da=9mm La=94mm Ztip=36mm Dbi=25mm → alim=4.94mm K=6.38MN/m m=3390g
#   [18/40] Dc=28mm Lc=160mm Da=9mm La=97mm Ztip=44mm Dbi=28mm → alim=4.19mm K=6.02MN/m m=3224g
#   [19/40] Dc=19mm Lc=37mm Da=5mm La=12mm Ztip=33mm Dbi=17mm → alim=1.69mm K=7.15MN/m m=3974g
#   [20/40] Dc=21mm Lc=49mm Da=6mm La=34mm Ztip=34mm Dbi=19mm → alim=3.96mm K=7.06MN/m m=3848g
#   [21/40] Dc=17mm Lc=56mm Da=9mm La=14mm Ztip=36mm Dbi=16mm → alim=2.80mm K=7.19MN/m m=4048g
#   [22/40] Dc=31mm Lc=154mm Da=8mm La=87mm Ztip=36mm Dbi=27mm → alim=4.09mm K=5.42MN/m m=2935g
#   [23/40] Dc=16mm Lc=20mm Da=5mm La=8mm Ztip=37mm Dbi=16mm → alim=1.80mm K=7.21MN/m m=4078g
#   [24/40] Dc=16mm Lc=50mm Da=8mm La=14mm Ztip=45mm Dbi=16mm → alim=3.53mm K=7.20MN/m m=4089g
#   [25/40] Dc=28mm Lc=166mm Da=10mm La=88mm Ztip=36mm Dbi=28mm → alim=3.48mm K=5.85MN/m m=3099g
#   [26/40] Dc=29mm Lc=168mm Da=10mm La=89mm Ztip=36mm Dbi=29mm → alim=2.76mm K=5.59MN/m m=2987g
#   [27/40] Dc=25mm Lc=153mm Da=9mm La=78mm Ztip=36mm Dbi=25mm → alim=5.00mm K=6.39MN/m m=3382g
#   [28/40] Dc=28mm Lc=161mm Da=10mm La=76mm Ztip=44mm Dbi=28mm → alim=2.50mm K=5.85MN/m m=3132g
#   [29/40] Dc=18mm Lc=23mm Da=5mm La=14mm Ztip=43mm Dbi=14mm → alim=2.51mm K=7.26MN/m m=4167g
#   [30/40] Dc=30mm Lc=160mm Da=9mm La=90mm Ztip=45mm Dbi=30mm → alim=3.92mm K=5.34MN/m m=2927g
#   [31/40] Dc=11mm Lc=44mm Da=6mm La=11mm Ztip=33mm Dbi=10mm → alim=2.66mm K=7.33MN/m m=4354g
#   [32/40] Dc=21mm Lc=58mm Da=7mm La=20mm Ztip=34mm Dbi=21mm → alim=3.36mm K=6.92MN/m m=3721g
#   [33/40] Dc=15mm Lc=27mm Da=6mm La=12mm Ztip=34mm Dbi=13mm → alim=3.05mm K=7.28MN/m m=4219g
#   [34/40] Dc=22mm Lc=55mm Da=6mm La=18mm Ztip=32mm Dbi=22mm → alim=2.46mm K=6.84MN/m m=3640g
#   [35/40] Dc=15mm Lc=31mm Da=6mm La=11mm Ztip=34mm Dbi=14mm → alim=2.41mm K=7.27MN/m m=4194g
#   [36/40] Dc=18mm Lc=50mm Da=5mm La=12mm Ztip=36mm Dbi=17mm → alim=2.46mm K=7.16MN/m m=3998g
#   [37/40] Dc=16mm Lc=37mm Da=6mm La=7mm Ztip=37mm Dbi=15mm → alim=1.51mm K=7.22MN/m m=4099g
#   [38/40] Dc=20mm Lc=66mm Da=8mm La=62mm Ztip=37mm Dbi=18mm → alim=5.00mm K=7.11MN/m m=3960g
#   [39/40] Dc=22mm Lc=53mm Da=6mm La=12mm Ztip=34mm Dbi=22mm → alim=1.36mm K=6.84MN/m m=3640g
#   [40/40] Dc=29mm Lc=162mm Da=10mm La=98mm Ztip=43mm Dbi=29mm → alim=2.73mm K=5.65MN/m m=3067g
# Gen 10/20 | best alim=5.00mm  best K=7.33MN/m  min m=2927g  |Pareto|=64
# Gen 11/20 — evaluating 40 offspring...
#   [ 1/40] Dc=18mm Lc=44mm Da=6mm La=31mm Ztip=35mm Dbi=18mm → alim=4.07mm K=7.14MN/m m=3976g
#   [ 2/40] Dc=32mm Lc=151mm Da=8mm La=90mm Ztip=36mm Dbi=27mm → alim=5.00mm K=5.36MN/m m=2909g
#   [ 3/40] Dc=10mm Lc=29mm Da=5mm La=11mm Ztip=36mm Dbi=10mm → alim=2.36mm K=7.33MN/m m=4375g
#   [ 4/40] Dc=24mm Lc=122mm Da=6mm La=73mm Ztip=37mm Dbi=24mm → alim=3.77mm K=6.61MN/m m=3487g
#   [ 5/40] Dc=17mm Lc=49mm Da=5mm La=11mm Ztip=34mm Dbi=16mm → alim=2.38mm K=7.19MN/m m=4034g
#   [ 6/40] Dc=21mm Lc=56mm Da=9mm La=14mm Ztip=36mm Dbi=17mm → alim=3.85mm K=7.14MN/m m=3947g
#   [ 7/40] Dc=28mm Lc=158mm Da=9mm La=96mm Ztip=36mm Dbi=27mm → alim=4.98mm K=6.02MN/m m=3185g
#   [ 8/40] Dc=29mm Lc=162mm Da=9mm La=98mm Ztip=43mm Dbi=29mm → alim=4.04mm K=5.61MN/m m=3035g
#   [ 9/40] Dc=25mm Lc=51mm Da=9mm La=12mm Ztip=45mm Dbi=25mm → alim=4.00mm K=6.51MN/m m=3437g
#   [10/40] Dc=30mm Lc=157mm Da=18mm La=91mm Ztip=48mm Dbi=30mm → alim=2.11mm K=5.35MN/m m=3210g
#   [11/40] Dc=21mm Lc=49mm Da=5mm La=11mm Ztip=34mm Dbi=17mm → alim=2.50mm K=7.14MN/m m=3937g
#   [12/40] Dc=22mm Lc=55mm Da=6mm La=11mm Ztip=34mm Dbi=22mm → alim=2.69mm K=6.86MN/m m=3656g
#   [13/40] Dc=29mm Lc=61mm Da=11mm La=10mm Ztip=37mm Dbi=26mm → alim=3.49mm K=6.19MN/m m=3169g
#   [14/40] Dc=29mm Lc=154mm Da=17mm La=92mm Ztip=48mm Dbi=29mm → alim=2.07mm K=5.59MN/m m=3279g
#   [15/40] Dc=15mm Lc=27mm Da=5mm La=9mm Ztip=37mm Dbi=13mm → alim=1.81mm K=7.28MN/m m=4223g
#   [16/40] Dc=22mm Lc=55mm Da=6mm La=12mm Ztip=34mm Dbi=22mm → alim=2.69mm K=6.86MN/m m=3657g
#   [17/40] Dc=21mm Lc=67mm Da=6mm La=33mm Ztip=35mm Dbi=19mm → alim=2.63mm K=7.05MN/m m=3839g
#   [18/40] Dc=28mm Lc=155mm Da=9mm La=95mm Ztip=36mm Dbi=28mm → alim=4.46mm K=5.99MN/m m=3164g
#   [19/40] Dc=10mm Lc=44mm Da=7mm La=26mm Ztip=33mm Dbi=10mm → alim=4.27mm K=7.33MN/m m=4385g
#   [20/40] Dc=10mm Lc=44mm Da=7mm La=24mm Ztip=33mm Dbi=10mm → alim=3.97mm K=7.33MN/m m=4385g
#   [21/40] Dc=10mm Lc=41mm Da=9mm La=25mm Ztip=35mm Dbi=10mm → alim=5.00mm K=7.33MN/m m=4388g
#   [22/40] Dc=26mm Lc=143mm Da=9mm La=93mm Ztip=43mm Dbi=26mm → alim=4.97mm K=6.30MN/m m=3373g
#   [23/40] Dc=10mm Lc=30mm Da=6mm La=8mm Ztip=36mm Dbi=10mm → alim=1.09mm K=7.33MN/m m=4370g
#   [24/40] Dc=29mm Lc=164mm Da=10mm La=93mm Ztip=36mm Dbi=29mm → alim=2.52mm K=5.64MN/m m=3016g
#   [25/40] Dc=17mm Lc=41mm Da=6mm La=26mm Ztip=32mm Dbi=17mm → alim=3.25mm K=7.14MN/m m=3971g
#   [26/40] Dc=21mm Lc=49mm Da=6mm La=37mm Ztip=38mm Dbi=19mm → alim=3.93mm K=7.05MN/m m=3853g
#   [27/40] Dc=24mm Lc=122mm Da=6mm La=71mm Ztip=37mm Dbi=24mm → alim=3.87mm K=6.59MN/m m=3473g
#   [28/40] Dc=29mm Lc=166mm Da=9mm La=85mm Ztip=38mm Dbi=29mm → alim=4.44mm K=5.81MN/m m=3073g
#   [29/40] Dc=15mm Lc=38mm Da=6mm La=5mm Ztip=37mm Dbi=15mm → alim=1.69mm K=7.25MN/m m=4151g
#   [30/40] Dc=29mm Lc=49mm Da=18mm La=12mm Ztip=48mm Dbi=26mm → alim=4.31mm K=6.20MN/m m=3269g
#   [31/40] Dc=22mm Lc=52mm Da=10mm La=19mm Ztip=42mm Dbi=21mm → alim=3.38mm K=6.94MN/m m=3760g
#   [32/40] Dc=30mm Lc=156mm Da=9mm La=89mm Ztip=49mm Dbi=30mm → alim=3.84mm K=5.43MN/m m=2982g
#   [33/40] Dc=15mm Lc=29mm Da=6mm La=12mm Ztip=33mm Dbi=13mm → alim=1.53mm K=7.28MN/m m=4218g
#   [34/40] Dc=17mm Lc=54mm Da=9mm La=14mm Ztip=36mm Dbi=16mm → alim=3.19mm K=7.19MN/m m=4049g
#   [35/40] Dc=17mm Lc=41mm Da=6mm La=33mm Ztip=35mm Dbi=17mm → alim=3.95mm K=7.15MN/m m=4000g
#   [36/40] Dc=30mm Lc=164mm Da=9mm La=99mm Ztip=39mm Dbi=29mm → alim=4.35mm K=5.39MN/m m=2929g
#   [37/40] Dc=30mm Lc=168mm Da=9mm La=91mm Ztip=36mm Dbi=27mm → alim=4.22mm K=5.50MN/m m=2993g
#   [38/40] Dc=30mm Lc=168mm Da=10mm La=95mm Ztip=36mm Dbi=29mm → alim=2.42mm K=5.53MN/m m=2980g
#   [39/40] Dc=21mm Lc=55mm Da=6mm La=15mm Ztip=34mm Dbi=21mm → alim=2.26mm K=6.87MN/m m=3665g
#   [40/40] Dc=28mm Lc=168mm Da=9mm La=93mm Ztip=36mm Dbi=28mm → alim=4.35mm K=5.85MN/m m=3102g
# Gen 11/20 | best alim=5.00mm  best K=7.33MN/m  min m=2909g  |Pareto|=70
# Gen 12/20 — evaluating 40 offspring...
#   [ 1/40] Dc=15mm Lc=27mm Da=6mm La=9mm Ztip=36mm Dbi=15mm → alim=2.16mm K=7.23MN/m m=4114g
#   [ 2/40] Dc=17mm Lc=56mm Da=8mm La=14mm Ztip=37mm Dbi=17mm → alim=2.57mm K=7.18MN/m m=4036g
#   [ 3/40] Dc=21mm Lc=52mm Da=5mm La=15mm Ztip=34mm Dbi=17mm → alim=2.93mm K=7.14MN/m m=3931g
#   [ 4/40] Dc=27mm Lc=157mm Da=9mm La=89mm Ztip=38mm Dbi=27mm → alim=4.92mm K=6.03MN/m m=3191g
#   [ 5/40] Dc=11mm Lc=31mm Da=6mm La=7mm Ztip=37mm Dbi=10mm → alim=1.71mm K=7.33MN/m m=4371g
#   [ 6/40] Dc=21mm Lc=54mm Da=6mm La=16mm Ztip=36mm Dbi=21mm → alim=2.78mm K=6.88MN/m m=3680g
#   [ 7/40] Dc=16mm Lc=37mm Da=5mm La=7mm Ztip=34mm Dbi=15mm → alim=1.38mm K=7.22MN/m m=4096g
#   [ 8/40] Dc=21mm Lc=49mm Da=6mm La=11mm Ztip=36mm Dbi=17mm → alim=2.84mm K=7.14MN/m m=3941g
#   [ 9/40] Dc=32mm Lc=151mm Da=8mm La=90mm Ztip=38mm Dbi=25mm → alim=1.94mm K=5.42MN/m m=2992g
#   [10/40] Dc=28mm Lc=168mm Da=9mm La=98mm Ztip=37mm Dbi=28mm → alim=3.07mm K=5.82MN/m m=3095g
#   [11/40] Dc=27mm Lc=168mm Da=9mm La=95mm Ztip=35mm Dbi=27mm → alim=4.34mm K=6.09MN/m m=3213g
#   [12/40] Dc=28mm Lc=168mm Da=9mm La=97mm Ztip=36mm Dbi=28mm → alim=3.97mm K=5.84MN/m m=3093g
#   [13/40] Dc=16mm Lc=37mm Da=6mm La=7mm Ztip=37mm Dbi=15mm → alim=2.04mm K=7.22MN/m m=4095g
#   [14/40] Dc=22mm Lc=73mm Da=10mm La=19mm Ztip=43mm Dbi=21mm → alim=4.14mm K=6.94MN/m m=3762g
#   [15/40] Dc=24mm Lc=120mm Da=6mm La=72mm Ztip=36mm Dbi=23mm → alim=3.51mm K=6.70MN/m m=3542g
#   [16/40] Dc=30mm Lc=162mm Da=13mm La=90mm Ztip=43mm Dbi=29mm → alim=1.94mm K=5.53MN/m m=3088g
#   [17/40] Dc=10mm Lc=33mm Da=6mm La=26mm Ztip=35mm Dbi=10mm → alim=3.32mm K=7.33MN/m m=4374g
# ...
#   [ 4/40] Dc=33mm Lc=160mm Da=6mm La=90mm Ztip=37mm Dbi=28mm → alim=2.59mm K=4.88MN/m m=2726g
#   [ 5/40] Dc=25mm Lc=149mm Da=8mm La=81mm Ztip=35mm Dbi=25mm → alim=4.74mm K=6.38MN/m m=3365g
#   [ 6/40] Dc=32mm Lc=163mm Da=9mm La=90mm Ztip=37mm Dbi=27mm → alim=3.90mm K=5.17MN/m m=2894g
#   [ 7/40] Dc=30mm Lc=150mm Da=8mm La=90mm Ztip=37mm Dbi=27mm → alim=4.60mm K=5.67MN/m m=3019g
#   [ 8/40] Dc=33mm Lc=163mm Da=9mm La=98mm Ztip=39mm Dbi=29mm → alim=3.41mm K=4.86MN/m m=2784g
#   [ 9/40] Dc=20mm Lc=57mm Da=8mm La=8mm Ztip=36mm Dbi=16mm → alim=2.98mm K=7.17MN/m m=3998g
#   [10/40] Dc=28mm Lc=166mm Da=9mm La=85mm Ztip=36mm Dbi=28mm → alim=4.50mm K=5.84MN/m m=3080g
#   [11/40] Dc=23mm Lc=114mm Da=6mm La=76mm Ztip=34mm Dbi=23mm → alim=4.65mm K=6.72MN/m m=3559g
#   [12/40] Dc=25mm Lc=151mm Da=9mm La=79mm Ztip=36mm Dbi=25mm → alim=5.00mm K=6.43MN/m m=3415g
#   [13/40] Dc=26mm Lc=150mm Da=8mm La=79mm Ztip=36mm Dbi=26mm → alim=4.62mm K=6.27MN/m m=3297g
#   [14/40] Dc=30mm Lc=151mm Da=8mm La=92mm Ztip=36mm Dbi=27mm → alim=4.89mm K=5.76MN/m m=3056g
#   [15/40] Dc=29mm Lc=152mm Da=8mm La=79mm Ztip=36mm Dbi=27mm → alim=4.05mm K=5.89MN/m m=3096g
#   [16/40] Dc=32mm Lc=169mm Da=9mm La=90mm Ztip=36mm Dbi=29mm → alim=3.51mm K=5.08MN/m m=2821g
#   [17/40] Dc=13mm Lc=28mm Da=5mm La=6mm Ztip=41mm Dbi=13mm → alim=1.45mm K=7.30MN/m m=4267g
#   [18/40] Dc=29mm Lc=159mm Da=9mm La=57mm Ztip=36mm Dbi=28mm → alim=3.88mm K=5.77MN/m m=3024g
#   [19/40] Dc=23mm Lc=53mm Da=6mm La=13mm Ztip=36mm Dbi=23mm → alim=2.11mm K=6.73MN/m m=3548g
#   [20/40] Dc=25mm Lc=115mm Da=9mm La=72mm Ztip=45mm Dbi=24mm → alim=5.00mm K=6.52MN/m m=3500g
#   [21/40] Dc=18mm Lc=41mm Da=5mm La=5mm Ztip=35mm Dbi=16mm → alim=1.28mm K=7.22MN/m m=4068g
#   [22/40] Dc=22mm Lc=42mm Da=6mm La=31mm Ztip=36mm Dbi=21mm → alim=3.40mm K=6.93MN/m m=3729g
#   [23/40] Dc=28mm Lc=149mm Da=8mm La=49mm Ztip=35mm Dbi=27mm → alim=3.43mm K=6.05MN/m m=3139g
#   [24/40] Dc=30mm Lc=167mm Da=9mm La=93mm Ztip=36mm Dbi=29mm → alim=4.11mm K=5.46MN/m m=2936g
#   [25/40] Dc=10mm Lc=33mm Da=8mm La=16mm Ztip=35mm Dbi=10mm → alim=4.07mm K=7.33MN/m m=4383g
#   [26/40] Dc=32mm Lc=151mm Da=9mm La=92mm Ztip=36mm Dbi=27mm → alim=4.81mm K=5.36MN/m m=2933g
#   [27/40] Dc=27mm Lc=151mm Da=9mm La=87mm Ztip=35mm Dbi=25mm → alim=4.47mm K=6.30MN/m m=3336g
#   [28/40] Dc=27mm Lc=163mm Da=9mm La=82mm Ztip=36mm Dbi=27mm → alim=5.00mm K=6.18MN/m m=3268g
#   [29/40] Dc=19mm Lc=57mm Da=8mm La=5mm Ztip=34mm Dbi=16mm → alim=2.54mm K=7.18MN/m m=4007g
#   [30/40] Dc=22mm Lc=50mm Da=10mm La=7mm Ztip=36mm Dbi=19mm → alim=3.09mm K=7.02MN/m m=3802g
#   [31/40] Dc=26mm Lc=156mm Da=8mm La=77mm Ztip=36mm Dbi=24mm → alim=4.15mm K=6.35MN/m m=3354g
#   [32/40] Dc=31mm Lc=151mm Da=11mm La=91mm Ztip=37mm Dbi=27mm → alim=5.00mm K=5.44MN/m m=3008g
#   [33/40] Dc=23mm Lc=110mm Da=6mm La=74mm Ztip=36mm Dbi=23mm → alim=4.32mm K=6.72MN/m m=3564g
#   [34/40] Dc=23mm Lc=114mm Da=6mm La=89mm Ztip=36mm Dbi=23mm → alim=5.00mm K=6.72MN/m m=3570g
#   [35/40] Dc=13mm Lc=32mm Da=5mm La=10mm Ztip=36mm Dbi=13mm → alim=1.99mm K=7.29MN/m m=4251g
#   [36/40] Dc=33mm Lc=146mm Da=8mm La=94mm Ztip=37mm Dbi=27mm → alim=3.99mm K=5.08MN/m m=2837g
#   [37/40] Dc=19mm Lc=57mm Da=8mm La=5mm Ztip=36mm Dbi=16mm → alim=1.75mm K=7.18MN/m m=4011g
#   [38/40] Dc=19mm Lc=57mm Da=8mm La=5mm Ztip=36mm Dbi=16mm → alim=1.73mm K=7.18MN/m m=4010g
#   [39/40] Dc=22mm Lc=76mm Da=8mm La=7mm Ztip=34mm Dbi=16mm → alim=3.72mm K=7.16MN/m m=3949g
#   [40/40] Dc=33mm Lc=148mm Da=9mm La=90mm Ztip=37mm Dbi=28mm → alim=4.07mm K=4.84MN/m m=2754g
# Gen 17/20 | best alim=5.00mm  best K=7.33MN/m  min m=2726g  |Pareto|=72
# Gen 18/20 — evaluating 40 offspring...
#   [ 1/40] Dc=31mm Lc=161mm Da=9mm La=92mm Ztip=36mm Dbi=27mm → alim=4.29mm K=5.29MN/m m=2910g
#   [ 2/40] Dc=32mm Lc=151mm Da=12mm La=96mm Ztip=36mm Dbi=28mm → alim=2.32mm K=5.15MN/m m=2943g
#   [ 3/40] Dc=27mm Lc=150mm Da=8mm La=81mm Ztip=35mm Dbi=25mm → alim=4.84mm K=6.26MN/m m=3290g
#   [ 4/40] Dc=27mm Lc=162mm Da=9mm La=86mm Ztip=40mm Dbi=27mm → alim=4.10mm K=6.19MN/m m=3287g
#   [ 5/40] Dc=18mm Lc=50mm Da=5mm La=7mm Ztip=34mm Dbi=13mm → alim=1.44mm K=7.27MN/m m=4159g
#   [ 6/40] Dc=33mm Lc=143mm Da=9mm La=95mm Ztip=36mm Dbi=27mm → alim=3.26mm K=5.08MN/m m=2845g
#   [ 7/40] Dc=12mm Lc=34mm Da=6mm La=6mm Ztip=31mm Dbi=12mm → alim=1.08mm K=7.30MN/m m=4274g
#   [ 8/40] Dc=25mm Lc=143mm Da=8mm La=84mm Ztip=35mm Dbi=25mm → alim=5.00mm K=6.40MN/m m=3382g
#   [ 9/40] Dc=13mm Lc=38mm Da=5mm La=8mm Ztip=37mm Dbi=11mm → alim=1.61mm K=7.32MN/m m=4319g
#   [10/40] Dc=30mm Lc=157mm Da=8mm La=96mm Ztip=39mm Dbi=29mm → alim=4.08mm K=5.52MN/m m=2970g
#   [11/40] Dc=22mm Lc=53mm Da=9mm La=9mm Ztip=35mm Dbi=20mm → alim=2.55mm K=6.99MN/m m=3767g
#   [12/40] Dc=25mm Lc=59mm Da=13mm La=11mm Ztip=45mm Dbi=24mm → alim=4.08mm K=6.58MN/m m=3481g
#   [13/40] Dc=13mm Lc=40mm Da=5mm La=9mm Ztip=36mm Dbi=11mm → alim=1.85mm K=7.32MN/m m=4332g
#   [14/40] Dc=30mm Lc=159mm Da=7mm La=98mm Ztip=36mm Dbi=30mm → alim=3.73mm K=5.54MN/m m=2908g
#   [15/40] Dc=13mm Lc=23mm Da=6mm La=14mm Ztip=31mm Dbi=12mm → alim=3.11mm K=7.30MN/m m=4278g
#   [16/40] Dc=26mm Lc=155mm Da=9mm La=84mm Ztip=36mm Dbi=25mm → alim=4.91mm K=6.36MN/m m=3368g
#   [17/40] Dc=22mm Lc=50mm Da=9mm La=7mm Ztip=36mm Dbi=19mm → alim=2.83mm K=7.05MN/m m=3832g
#   [18/40] Dc=25mm Lc=54mm Da=10mm La=11mm Ztip=45mm Dbi=25mm → alim=2.96mm K=6.50MN/m m=3426g
#   [19/40] Dc=25mm Lc=50mm Da=8mm La=23mm Ztip=37mm Dbi=24mm → alim=4.18mm K=6.59MN/m m=3457g
#   [20/40] Dc=28mm Lc=153mm Da=8mm La=53mm Ztip=45mm Dbi=27mm → alim=3.27mm K=6.02MN/m m=3185g
#   [21/40] Dc=16mm Lc=45mm Da=5mm La=12mm Ztip=34mm Dbi=15mm → alim=2.24mm K=7.23MN/m m=4106g
#   [22/40] Dc=24mm Lc=115mm Da=6mm La=67mm Ztip=36mm Dbi=23mm → alim=3.85mm K=6.70MN/m m=3538g
#   [23/40] Dc=26mm Lc=150mm Da=8mm La=70mm Ztip=35mm Dbi=26mm → alim=4.24mm K=6.27MN/m m=3281g
#   [24/40] Dc=33mm Lc=148mm Da=9mm La=90mm Ztip=37mm Dbi=28mm → alim=4.18mm K=4.84MN/m m=2754g
#   [25/40] Dc=10mm Lc=33mm Da=9mm La=9mm Ztip=35mm Dbi=10mm → alim=3.39mm K=7.33MN/m m=4373g
#   [26/40] Dc=22mm Lc=58mm Da=10mm La=23mm Ztip=35mm Dbi=20mm → alim=4.76mm K=6.97MN/m m=3775g
#   [27/40] Dc=30mm Lc=148mm Da=9mm La=90mm Ztip=36mm Dbi=28mm → alim=4.53mm K=5.58MN/m m=2984g
#   [28/40] Dc=33mm Lc=150mm Da=9mm La=96mm Ztip=37mm Dbi=28mm → alim=3.71mm K=4.81MN/m m=2751g
#   [29/40] Dc=27mm Lc=153mm Da=8mm La=90mm Ztip=35mm Dbi=27mm → alim=4.87mm K=6.07MN/m m=3186g
#   [30/40] Dc=29mm Lc=168mm Da=10mm La=89mm Ztip=36mm Dbi=28mm → alim=2.61mm K=5.64MN/m m=3030g
#   [31/40] Dc=26mm Lc=151mm Da=9mm La=87mm Ztip=36mm Dbi=25mm → alim=4.77mm K=6.33MN/m m=3357g
#   [32/40] Dc=32mm Lc=151mm Da=9mm La=92mm Ztip=36mm Dbi=27mm → alim=4.71mm K=5.30MN/m m=2908g
#   [33/40] Dc=16mm Lc=47mm Da=5mm La=5mm Ztip=34mm Dbi=15mm → alim=1.27mm K=7.22MN/m m=4095g
#   [34/40] Dc=29mm Lc=157mm Da=9mm La=57mm Ztip=36mm Dbi=27mm → alim=3.03mm K=5.73MN/m m=3019g
#   [35/40] Dc=13mm Lc=32mm Da=5mm La=12mm Ztip=36mm Dbi=13mm → alim=2.41mm K=7.29MN/m m=4238g
#   [36/40] Dc=16mm Lc=50mm Da=5mm La=9mm Ztip=38mm Dbi=16mm → alim=1.86mm K=7.22MN/m m=4091g
#   [37/40] Dc=20mm Lc=62mm Da=9mm La=10mm Ztip=34mm Dbi=19mm → alim=3.06mm K=7.03MN/m m=3827g
#   [38/40] Dc=27mm Lc=160mm Da=10mm La=79mm Ztip=35mm Dbi=26mm → alim=3.76mm K=6.21MN/m m=3297g
#   [39/40] Dc=25mm Lc=67mm Da=8mm La=15mm Ztip=37mm Dbi=25mm → alim=3.16mm K=6.51MN/m m=3403g
#   [40/40] Dc=32mm Lc=149mm Da=9mm La=93mm Ztip=45mm Dbi=30mm → alim=3.90mm K=5.05MN/m m=2844g
# Gen 18/20 | best alim=5.00mm  best K=7.33MN/m  min m=2726g  |Pareto|=69
# Gen 19/20 — evaluating 40 offspring...
#   [ 1/40] Dc=16mm Lc=48mm Da=5mm La=13mm Ztip=34mm Dbi=16mm → alim=2.55mm K=7.22MN/m m=4092g
#   [ 2/40] Dc=26mm Lc=159mm Da=8mm La=82mm Ztip=35mm Dbi=26mm → alim=4.59mm K=6.25MN/m m=3285g
#   [ 3/40] Dc=11mm Lc=32mm Da=10mm La=20mm Ztip=35mm Dbi=10mm → alim=5.00mm K=7.33MN/m m=4387g
#   [ 4/40] Dc=30mm Lc=152mm Da=9mm La=84mm Ztip=36mm Dbi=26mm → alim=4.35mm K=5.66MN/m m=3040g
#   [ 5/40] Dc=22mm Lc=50mm Da=5mm La=31mm Ztip=36mm Dbi=22mm → alim=3.10mm K=6.83MN/m m=3642g
#   [ 6/40] Dc=26mm Lc=143mm Da=9mm La=87mm Ztip=36mm Dbi=25mm → alim=5.00mm K=6.35MN/m m=3357g
#   [ 7/40] Dc=32mm Lc=150mm Da=9mm La=95mm Ztip=36mm Dbi=27mm → alim=4.69mm K=5.30MN/m m=2911g
#   [ 8/40] Dc=33mm Lc=151mm Da=9mm La=96mm Ztip=37mm Dbi=28mm → alim=4.37mm K=4.78MN/m m=2751g
#   [ 9/40] Dc=20mm Lc=56mm Da=8mm La=11mm Ztip=35mm Dbi=17mm → alim=3.55mm K=7.16MN/m m=3981g
#   [10/40] Dc=26mm Lc=160mm Da=7mm La=80mm Ztip=36mm Dbi=26mm → alim=3.89mm K=6.25MN/m m=3263g
#   [11/40] Dc=24mm Lc=118mm Da=6mm La=73mm Ztip=32mm Dbi=21mm → alim=5.00mm K=6.82MN/m m=3616g
#   [12/40] Dc=33mm Lc=159mm Da=7mm La=89mm Ztip=37mm Dbi=28mm → alim=3.22mm K=4.78MN/m m=2726g
#   [13/40] Dc=25mm Lc=55mm Da=6mm La=15mm Ztip=35mm Dbi=23mm → alim=2.79mm K=6.72MN/m m=3525g
#   [14/40] Dc=27mm Lc=149mm Da=9mm La=85mm Ztip=36mm Dbi=25mm → alim=5.00mm K=6.31MN/m m=3343g
#   [15/40] Dc=30mm Lc=150mm Da=6mm La=90mm Ztip=38mm Dbi=27mm → alim=2.76mm K=5.66MN/m m=2996g
#   [16/40] Dc=33mm Lc=160mm Da=8mm La=81mm Ztip=37mm Dbi=28mm → alim=3.41mm K=4.87MN/m m=2749g
#   [17/40] Dc=21mm Lc=45mm Da=6mm La=33mm Ztip=36mm Dbi=21mm → alim=3.66mm K=6.94MN/m m=3743g
#   [18/40] Dc=30mm Lc=166mm Da=10mm La=86mm Ztip=35mm Dbi=29mm → alim=2.78mm K=5.42MN/m m=2915g
#   [19/40] Dc=22mm Lc=82mm Da=9mm La=6mm Ztip=34mm Dbi=15mm → alim=2.23mm K=7.19MN/m m=3996g
#   [20/40] Dc=29mm Lc=152mm Da=10mm La=58mm Ztip=36mm Dbi=28mm → alim=4.08mm K=5.78MN/m m=3046g
#   [21/40] Dc=25mm Lc=118mm Da=7mm La=72mm Ztip=32mm Dbi=21mm → alim=5.00mm K=6.80MN/m m=3611g
#   [22/40] Dc=33mm Lc=149mm Da=9mm La=97mm Ztip=37mm Dbi=28mm → alim=3.90mm K=4.86MN/m m=2770g
#   [23/40] Dc=22mm Lc=42mm Da=6mm La=7mm Ztip=36mm Dbi=19mm → alim=2.04mm K=7.06MN/m m=3841g
#   [24/40] Dc=25mm Lc=50mm Da=9mm La=30mm Ztip=36mm Dbi=21mm → alim=4.27mm K=6.91MN/m m=3688g
#   [25/40] Dc=27mm Lc=150mm Da=8mm La=51mm Ztip=35mm Dbi=27mm → alim=3.75mm K=6.07MN/m m=3151g
#   [26/40] Dc=34mm Lc=150mm Da=9mm La=97mm Ztip=37mm Dbi=28mm → alim=3.83mm K=4.77MN/m m=2750g
#   [27/40] Dc=23mm Lc=31mm Da=6mm La=12mm Ztip=36mm Dbi=23mm → alim=2.92mm K=6.76MN/m m=3572g
#   [28/40] Dc=29mm Lc=164mm Da=9mm La=59mm Ztip=36mm Dbi=28mm → alim=3.59mm K=5.76MN/m m=3023g
#   [29/40] Dc=23mm Lc=56mm Da=9mm La=22mm Ztip=36mm Dbi=14mm → alim=4.37mm K=7.22MN/m m=4059g
#   [30/40] Dc=33mm Lc=150mm Da=9mm La=100mm Ztip=37mm Dbi=28mm → alim=4.26mm K=4.95MN/m m=2791g
#   [31/40] Dc=13mm Lc=32mm Da=5mm La=6mm Ztip=36mm Dbi=10mm → alim=1.44mm K=7.33MN/m m=4355g
#   [32/40] Dc=22mm Lc=43mm Da=6mm La=30mm Ztip=36mm Dbi=21mm → alim=3.20mm K=6.90MN/m m=3702g
#   [33/40] Dc=32mm Lc=150mm Da=9mm La=90mm Ztip=37mm Dbi=28mm → alim=5.00mm K=5.18MN/m m=2856g
#   [34/40] Dc=32mm Lc=159mm Da=9mm La=96mm Ztip=37mm Dbi=30mm → alim=4.06mm K=4.89MN/m m=2745g
#   [35/40] Dc=22mm Lc=50mm Da=9mm La=7mm Ztip=36mm Dbi=20mm → alim=2.55mm K=6.97MN/m m=3752g
#   [36/40] Dc=32mm Lc=149mm Da=9mm La=92mm Ztip=33mm Dbi=25mm → alim=3.60mm K=5.50MN/m m=3008g
#   [37/40] Dc=16mm Lc=45mm Da=5mm La=12mm Ztip=34mm Dbi=15mm → alim=2.59mm K=7.23MN/m m=4109g
#   [38/40] Dc=24mm Lc=53mm Da=6mm La=13mm Ztip=36mm Dbi=23mm → alim=2.24mm K=6.73MN/m m=3542g
#   [39/40] Dc=25mm Lc=50mm Da=8mm La=21mm Ztip=36mm Dbi=24mm → alim=3.75mm K=6.59MN/m m=3451g
#   [40/40] Dc=32mm Lc=150mm Da=9mm La=99mm Ztip=37mm Dbi=28mm → alim=4.63mm K=5.18MN/m m=2870g
# Gen 19/20 | best alim=5.00mm  best K=7.33MN/m  min m=2726g  |Pareto|=70
# Gen 20/20 — evaluating 40 offspring...
#   [ 1/40] Dc=10mm Lc=33mm Da=9mm La=23mm Ztip=35mm Dbi=10mm → alim=5.00mm K=7.33MN/m m=4393g
#   [ 2/40] Dc=10mm Lc=33mm Da=10mm La=23mm Ztip=35mm Dbi=10mm → alim=4.32mm K=7.33MN/m m=4397g
#   [ 3/40] Dc=27mm Lc=151mm Da=8mm La=90mm Ztip=35mm Dbi=27mm → alim=4.47mm K=6.18MN/m m=3246g
#   [ 4/40] Dc=34mm Lc=151mm Da=8mm La=96mm Ztip=37mm Dbi=28mm → alim=5.00mm K=4.63MN/m m=2692g
#   [ 5/40] Dc=30mm Lc=163mm Da=9mm La=97mm Ztip=38mm Dbi=29mm → alim=4.45mm K=5.49MN/m m=2961g
#   [ 6/40] Dc=28mm Lc=150mm Da=8mm La=52mm Ztip=35mm Dbi=27mm → alim=5.00mm K=6.05MN/m m=3145g
#   [ 7/40] Dc=29mm Lc=151mm Da=9mm La=96mm Ztip=35mm Dbi=25mm → alim=4.12mm K=5.91MN/m m=3169g
#   [ 8/40] Dc=33mm Lc=151mm Da=9mm La=96mm Ztip=32mm Dbi=29mm → alim=3.69mm K=4.80MN/m m=2688g
#   [ 9/40] Dc=23mm Lc=33mm Da=6mm La=11mm Ztip=38mm Dbi=22mm → alim=2.56mm K=6.77MN/m m=3593g
#   [10/40] Dc=27mm Lc=158mm Da=9mm La=83mm Ztip=36mm Dbi=27mm → alim=4.74mm K=6.14MN/m m=3236g
#   [11/40] Dc=25mm Lc=51mm Da=8mm La=24mm Ztip=36mm Dbi=24mm → alim=4.45mm K=6.61MN/m m=3464g
#   [12/40] Dc=29mm Lc=167mm Da=10mm La=88mm Ztip=37mm Dbi=29mm → alim=2.66mm K=5.60MN/m m=3002g
#   [13/40] Dc=10mm Lc=27mm Da=10mm La=21mm Ztip=35mm Dbi=10mm → alim=5.00mm K=7.33MN/m m=4393g
#   [14/40] Dc=28mm Lc=156mm Da=9mm La=51mm Ztip=39mm Dbi=27mm → alim=2.62mm K=6.04MN/m m=3169g
#   [15/40] Dc=32mm Lc=157mm Da=6mm La=90mm Ztip=36mm Dbi=27mm → alim=3.14mm K=5.22MN/m m=2858g
#   [16/40] Dc=33mm Lc=159mm Da=9mm La=92mm Ztip=37mm Dbi=28mm → alim=3.90mm K=4.87MN/m m=2767g
#   [17/40] Dc=33mm Lc=151mm Da=9mm La=101mm Ztip=37mm Dbi=29mm → alim=3.81mm K=4.75MN/m m=2732g
#   [18/40] Dc=32mm Lc=151mm Da=9mm La=75mm Ztip=36mm Dbi=27mm → alim=4.29mm K=5.36MN/m m=2916g
#   [19/40] Dc=23mm Lc=75mm Da=8mm La=7mm Ztip=34mm Dbi=18mm → alim=2.72mm K=7.09MN/m m=3850g
#   [20/40] Dc=28mm Lc=155mm Da=9mm La=52mm Ztip=35mm Dbi=26mm → alim=3.83mm K=6.07MN/m m=3167g
#   [21/40] Dc=25mm Lc=143mm Da=8mm La=52mm Ztip=35mm Dbi=25mm → alim=3.77mm K=6.40MN/m m=3347g
#   [22/40] Dc=28mm Lc=150mm Da=8mm La=84mm Ztip=35mm Dbi=27mm → alim=4.30mm K=5.99MN/m m=3146g
#   [23/40] Dc=29mm Lc=152mm Da=10mm La=58mm Ztip=36mm Dbi=28mm → alim=4.60mm K=5.78MN/m m=3046g
#   [24/40] Dc=29mm Lc=154mm Da=10mm La=58mm Ztip=36mm Dbi=28mm → alim=4.17mm K=5.78MN/m m=3045g
#   [25/40] Dc=13mm Lc=27mm Da=5mm La=9mm Ztip=36mm Dbi=13mm → alim=2.08mm K=7.29MN/m m=4251g
#   [26/40] Dc=32mm Lc=152mm Da=9mm La=92mm Ztip=36mm Dbi=27mm → alim=4.69mm K=5.29MN/m m=2904g
#   [27/40] Dc=30mm Lc=150mm Da=9mm La=96mm Ztip=36mm Dbi=28mm → alim=4.85mm K=5.64MN/m m=3010g
#   [28/40] Dc=32mm Lc=163mm Da=9mm La=98mm Ztip=39mm Dbi=29mm → alim=3.69mm K=4.95MN/m m=2806g
#   [29/40] Dc=13mm Lc=34mm Da=5mm La=6mm Ztip=35mm Dbi=11mm → alim=1.41mm K=7.32MN/m m=4339g
#   [30/40] Dc=28mm Lc=148mm Da=8mm La=52mm Ztip=34mm Dbi=28mm → alim=3.77mm K=5.97MN/m m=3093g
#   [31/40] Dc=27mm Lc=151mm Da=8mm La=90mm Ztip=35mm Dbi=27mm → alim=3.75mm K=6.09MN/m m=3197g
#   [32/40] Dc=32mm Lc=151mm Da=9mm La=92mm Ztip=36mm Dbi=27mm → alim=4.70mm K=5.32MN/m m=2914g
#   [33/40] Dc=32mm Lc=151mm Da=6mm La=60mm Ztip=36mm Dbi=28mm → alim=2.51mm K=5.23MN/m m=2806g
#   [34/40] Dc=33mm Lc=160mm Da=10mm La=88mm Ztip=37mm Dbi=29mm → alim=2.96mm K=4.79MN/m m=2760g
#   [35/40] Dc=17mm Lc=45mm Da=5mm La=8mm Ztip=36mm Dbi=13mm → alim=1.14mm K=7.29MN/m m=4211g
#   [36/40] Dc=30mm Lc=156mm Da=10mm La=57mm Ztip=36mm Dbi=29mm → alim=4.00mm K=5.59MN/m m=2952g
#   [37/40] Dc=13mm Lc=27mm Da=5mm La=12mm Ztip=37mm Dbi=12mm → alim=2.47mm K=7.31MN/m m=4294g
#   [38/40] Dc=13mm Lc=28mm Da=6mm La=10mm Ztip=36mm Dbi=11mm → alim=2.16mm K=7.32MN/m m=4319g
#   [39/40] Dc=13mm Lc=36mm Da=5mm La=7mm Ztip=36mm Dbi=12mm → alim=1.55mm K=7.30MN/m m=4273g
#   [40/40] Dc=32mm Lc=155mm Da=9mm La=93mm Ztip=39mm Dbi=30mm → alim=3.90mm K=4.90MN/m m=2757g
# Gen 20/20 | best alim=5.00mm  best K=7.33MN/m  min m=2688g  |Pareto|=68
#
# ======================================================================
# FINAL RESULTS — GA Multi-Objective Optimization (static bar)
# ======================================================================
#   Criterion           Dc[mm]  Lc[mm]  Da[mm]  La[mm] alim[mm] K[MN/m]   m[g]
#   --------------------------------------------------------------------
#   Max alim              28.6    85.8    28.6    60.1    5.000   5.796   3605
#   Max stiffness         10.2    32.8     8.9    23.3    5.000   7.329   4393
#   Min mass              33.4   151.3     8.9    96.1    3.692   4.795   2688
#   ★ Best balanced       24.6   110.7     6.0    73.9    5.000   6.686   3526
#
#   Pareto front (final): 40 individuals
#   Total evaluations:   840
#
#   Best absorber tuning: kd=5.803e+04 N/m  cd=27778 Ns/m  md=33 g
# ======================================================================

# %%
make_plots(all_results, pareto_front, history)
